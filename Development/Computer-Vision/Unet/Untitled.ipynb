# %% [markdown]
# # Understanding the images

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
im=cv2.imread('images/Abyssinian_101.jpg')

# %%
plt.imshow(im)

# %%
im.shape
# Out:
# (313, 450, 3)

# %%
mask=np.zeros((313,450))
plt.imshow(mask)

# %%
plt.imshow(cv2.rectangle(im,(54,36),(319,235),(255,255,255),4))
