# %% [markdown]
# # Test Cases

# %%
import sys
from mylist import *
from mycrm import *
from myserver import *
from myvm import *

from inspect import currentframe, getframeinfo

# test.py for toy cloud assignment.
# feel free to comment the relevant parts in main function.

## test helper functions

global test_no
global crm
test_no=0
def mycheck(result, msg, lno=0):
    global test_no
    test_no += 1
    cf=currentframe()
    l1=cf.f_back.f_lineno
    if lno:
        l=f'{lno},{l1}'
    else:
        l=f'{l1}'
    if result:
        print(f'{l} tno: {test_no} {msg} PASSED ')
    else:
        print(f'{l}: tno: {test_no} {msg} FAILED ')
        sys.exit(1)

# template crmstat to copy and change values.
#mys=crm_stat(stotal=1,sidle=1,sactive=0,sfail=0,vtotal=1,vprovision=1,vactive=0,'vidle', vdeleted=0)
#print(mys)


def check_stat(s1):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_stat()
    mycheck((s==s1),f'{s1} == {s}', lno)

def check_server_count(count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_servers(state)
    mycheck(len(s) == count, f'server_count {len(s)} == {count} for state {state}', lno)

    s=crm.get_servers('any')
    c=0
    for i in s:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c == count, f'server_count {c} == {count} for state {state}', lno)

def check_server_state(sname, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    assert(state != 'any')
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sname and i.state == state:
            f=1
            break
    mycheck(f==1, f'server {sname} with state {state} found', lno)
    s=crm.get_servers(state)
    f=0
    for i in s:
        if i.sc.name == sname and i.state == state:
            f=1
            break
    mycheck(f==1, f'server {sname} with state {state} found', lno)

def check_vm_count(count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_vms(state)
    mycheck(len(s) == count, f'vm count {len(s)} == {count} for state {state}', lno)

    s=crm.get_vms('any')
    c=0
    for i in s:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms(state)
        for j in v:
            c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms('any')
        for j in v:
            if state != 'any' and j.state != state:
                continue
            c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)



def check_server_vm_count(sr, count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=fs.get_vms('any')
    c=0
    for i in v:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c==count, f'vm count in {sr} {c} == {count} for state={state}', lno) 
    if state == 'any':
        return
    v=fs.get_vms(state)
    c=0
    for i in v:
        c += 1
    mycheck(c==count, f'vm count in {sr} {c} == {count} for state={state}', lno) 

def check_server_vm_state(sr, vm, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=crm.get_vms('any')
    f=0
    for i in v:
        if i.vc.name == vm:
            f=1
            fv=i
            break
    if f != 1:
        mycheck(0, f'vm {vm} in {sr} lookup', lno)
    mycheck(fv.state==state, f'vm: {fv.vc.name} state {fv.state} == {state}', lno) 

def check_novm(vm):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_vms('any')
    c=0
    for i in s:
        if i.vc.name == vm:
            c += 1
    mycheck(c == 0, f'vm {vm} not present', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms('any')
        for j in v:
            if j.vc.name == vm:
                c += 1
    mycheck(c == 0, f'vm {vm} not present', lno)

def check_server_novm(sr, vm):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=crm.get_vms('any')
    f=0
    for i in v:
        if i.vc.name == vm:
            f=1
            fv=i
            break
    mycheck(f==0, f'vm: {vm}  in server {sr} not present', lno) 

aggr=namedtuple('aggr', 'ncpu mem')
vmt=namedtuple('vmt', 'ncpu mem')
testvm=namedtuple('testvm', 'vc pvm')

def get_available():
    available_cpus=0
    available_mem=0
    avails=[]
    s=crm.get_servers('any')
    for i in s:
        available_cpus += i.acpu
        available_mem += i.amem
        avails.append(sconf(i.sc.name, i.acpu, i.amem))

    print(avails)
    y=aggr(available_cpus, available_mem)
    return y

# %% [markdown]
# #

# %% [markdown]
# # Last Test

# %%
global crm
crm=mycrm()
# 10 servers, 1000 vms
ps=[]
nservers=10
for i in range(0,nservers):
    sname=f's{i}'
    a = crm.add(sname, 150+i*50, 1000+2*i*200)
    ps.append(a)
print (f'Physical Servers: {ps}')
total_memory=0
total_cpu=0
for i in ps:
    total_memory +=i.sc.mem
    total_cpu += i.sc.ncpu
total = aggr(total_cpu,total_memory)
print (total)
t1=vmt(2, 4)
t2=vmt(4,16)
t3=vmt(8,64)
t4=vmt(16,128)
t5=vmt(32,256)
t6=vmt(64,512)
t7=vmt(128,1024)
vmtypes=[t1, t2, t3, t4, t5, t6, t7]
print(vmtypes)
# keep allocating until we run out of space
i=0
v=0
vms=[]
pvms=[]
mod=len(vmtypes) 
while True:
    vname=f'vm{v}'
    ncpu=vmtypes[i].ncpu
    mem=vmtypes[i].mem
    vm = crm.provision_vm(vname, ncpu, mem)
    if vm == None:
        print(f'provisioning failed for {vmtypes[i]}')
        mod -= 1
        if mod == 0:
            break
    else:
        tvm=testvm(vm.vc,vm)
        vms.append(tvm)
        pvms.append(vm)
        v += 1
    i=(i+1)%mod


allocated_cpus=0
allocated_mem=0
#    print(vms)
for v in pvms:
    allocated_cpus += v.vc.ncpu 
    allocated_mem += v.vc.mem 

allocated=aggr(allocated_cpus, allocated_mem)
available=get_available()
print(f'allocated:{allocated} Total: {total} available:{available}')
check_stat(crm_stat(stotal=nservers,sidle=nservers,sactive=0,sfail=0,vtotal=len(vms),vprovision=len(vms),vactive=0, vdeleted=0))

vmtypes=[t1, t2, t3, t4, t5, t6, t7]
for s in ps:
    check_server_state(s.sc.name, 'idle')
    check_vm_count(len(vms), 'provision')
    check_vm_count(len(vms), 'any')
    for v in s.get_vms('any'):
        check_server_vm_state(s.sc.name, v.vc.name, 'provision')
    check_server_vm_count(s.sc.name, s.nvms, 'provision')
    mycheck(((s.acpu < vmtypes[0].ncpu) or (s.amem < vmtypes[0].mem)),
            f'Server {s.sc.name, s.acpu, s.amem} available < min vm {vmtypes[0].ncpu}')

#undo last 10 operations

crm.provision_undo(10)
check_stat(crm_stat(stotal=nservers,sidle=nservers,sactive=0,sfail=0,vtotal=len(vms)-10,vprovision=len(vms)-10,vactive=0, vdeleted=10))

# verify that the last 10 vms are not present

for i in range(0,10):	
    v=vms[-i-1]
    pv=pvms[-i-1]
    check_novm(v.vc.name)
    mycheck((pv.state=='deleted'), f'vm {pv.vc.name} state {pv.state} == deleted')
#provision these vms again in the same order as before
for i in range(0,10):
    v=vms[len(vms)-10+i]
    print(f'recreating {v.vc.name}')
    vm = crm.provision_vm(v.vc.name, v.vc.ncpu, v.vc.mem)
    tvm=testvm(vm.vc,vm)
    vms[len(pvms)-10+i]=tvm
    pvms[len(pvms)-10+i]=vm
check_stat(crm_stat(stotal=nservers,sidle=nservers,sactive=0,sfail=0,vtotal=len(vms),vprovision=len(vms),vactive=0,
    vdeleted=10))


#now consume all cpus
v=len(vms)
print(v)
while True:
    vname=f'vm{v}'
    ncpu=1
    mem=1
    vm = crm.provision_vm(vname, ncpu, mem)
    if vm == None:
        print(f'provisioning failed for {vname, ncpu, mem}')
        break
    tvm=testvm(vm.vc,vm)
    vms.append(tvm)
    pvms.append(vm)
    v += 1
print(f'Provisioned total of {v} more vms')

allocated_cpus=0
allocated_mem=0
#    print(vms)
for v in pvms:
    allocated_cpus += v.vc.ncpu 
    allocated_mem += v.vc.mem 

allocated=aggr(allocated_cpus, allocated_mem)
available=get_available()
print(f'allocated:{allocated} Total: {total} available:{available}')
check_stat(crm_stat(stotal=nservers,sidle=nservers,sactive=0,sfail=0,vtotal=len(vms),vprovision=len(vms),vactive=0, vdeleted=10))

#commit all the vms

crm.commit_provisioned_vms()
check_stat(crm_stat(stotal=nservers,sidle=0,sactive=nservers,sfail=0,vtotal=len(vms),vprovision=0,vactive=len(vms), vdeleted=10))

# fail a server.
for p in ps:
    print(f'server: {p.sc.name}')

print(f'Failing few servers')
nvms=ps[0].nvms+ps[1].nvms
crm.fail(ps[0].sc.name)
crm.fail(ps[1].sc.name)
check_stat(crm_stat(stotal=nservers,sidle=0,sactive=nservers-2,sfail=2,vtotal=len(vms),vprovision=0,vactive=len(vms)-nvms,vidle=nvms, vdeleted=10))
idlevms=crm.get_vms('idle')
mycheck(len(idlevms)==nvms, f'idlevms count{len(idlevms)} match {nvms} vms in failed servers')




print(f'Deleting few servers')
crm.delete_server(ps[0].sc.name)
print(f'Deleting few servers')
crm.delete_server(ps[1].sc.name)
check_stat(crm_stat(stotal=nservers-2,sidle=0,sactive=nservers-2,sfail=0,sdeleted=2,vtotal=len(vms),vprovision=0,vactive=len(vms)-nvms,vidle=nvms, vdeleted=10))

#now delete some 10 vms
print(f'deleting 10 vms')
for i in range(0,9):
    crm.delete_vm(f'vm{i}')
# delete one of this idle vms.

idlevms=crm.get_vms('idle')
v1=idlevms[0]
print(f'deleting {v1.vc.name}')
crm.delete_vm(v1.vc.name)
nvms -= 1

# delete one idle vm

check_stat(crm_stat(stotal=nservers-2,sidle=0,sactive=nservers-2,sfail=0,sdeleted=2,vtotal=len(vms)-10,vprovision=0,vactive=len(vms)-nvms-10,vidle=nvms, vdeleted=20))
# Out:
# Physical Servers: [<myserver.myserver object at 0x7fe1e812f370>, <myserver.myserver object at 0x7fe1e812f880>, <myserver.myserver object at 0x7fe1e812f6d0>, <myserver.myserver object at 0x7fe1e812fb20>, <myserver.myserver object at 0x7fe1e812fc70>, <myserver.myserver object at 0x7fe1e812fdf0>, <myserver.myserver object at 0x7fe1e812ff40>, <myserver.myserver object at 0x7fe1e8134040>, <myserver.myserver object at 0x7fe1e8134190>, <myserver.myserver object at 0x7fe1e81342e0>]
# aggr(ncpu=3750, mem=28000)
# [vmt(ncpu=2, mem=4), vmt(ncpu=4, mem=16), vmt(ncpu=8, mem=64), vmt(ncpu=16, mem=128), vmt(ncpu=32, mem=256), vmt(ncpu=64, mem=512), vmt(ncpu=128, mem=1024)]
# provisioning failed for vmt(ncpu=128, mem=1024)
# provisioning failed for vmt(ncpu=64, mem=512)
# provisioning failed for vmt(ncpu=32, mem=256)
# provisioning failed for vmt(ncpu=8, mem=64)
# provisioning failed for vmt(ncpu=8, mem=64)
# provisioning failed for vmt(ncpu=4, mem=16)
# provisioning failed for vmt(ncpu=2, mem=4)
# [sconf(name='s9', ncpu=4, mem=0), sconf(name='s8', ncpu=18, mem=0), sconf(name='s7', ncpu=20, mem=0), sconf(name='s6', ncpu=22, mem=0), sconf(name='s5', ncpu=16, mem=0), sconf(name='s4', ncpu=18, mem=0), sconf(name='s3', ncpu=20, mem=0), sconf(name='s2', ncpu=22, mem=0), sconf(name='s1', ncpu=16, mem=0), sconf(name='s0', ncpu=18, mem=0)]
# allocated:aggr(ncpu=3576, mem=28000) Total: aggr(ncpu=3750, mem=28000) available:aggr(ncpu=174, mem=0)
# 61,41 tno: 1 crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=120, vprovision=120, vactive=0, vidle=0, vdeleted=0) == crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=120, vprovision=120, vactive=0, vidle=0, vdeleted=0) PASSED
# 65,68 tno: 2 server s0 with state idle found PASSED
# 65,75 tno: 3 server s0 with state idle found PASSED
# 66,81 tno: 4 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 5 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 6 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 7 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 8 vm count 120 == 120 for state any PASSED
# 67,89 tno: 9 vm count 120 == 120 for state any PASSED
# 67,96 tno: 10 vm count 120 == 120 for state any PASSED
# 67,105 tno: 11 vm count 120 == 120 for state any PASSED
# 69,160 tno: 12 vm: vm119 state provision == provision PASSED
# 69,160 tno: 13 vm: vm118 state provision == provision PASSED
# 69,160 tno: 14 vm: vm111 state provision == provision PASSED
# 69,160 tno: 15 vm: vm110 state provision == provision PASSED
# 69,160 tno: 16 vm: vm106 state provision == provision PASSED
# 69,160 tno: 17 vm: vm105 state provision == provision PASSED
# 69,160 tno: 18 vm: vm100 state provision == provision PASSED
# 69,160 tno: 19 vm: vm96 state provision == provision PASSED
# 70,129 tno: 20 vm count in s0 8 == 8 for state=provision PASSED
# 70,136 tno: 21 vm count in s0 8 == 8 for state=provision PASSED
# 71 tno: 22 Server ('s0', 18, 0) available < min vm 2 PASSED
# 65,68 tno: 23 server s1 with state idle found PASSED
# 65,75 tno: 24 server s1 with state idle found PASSED
# 66,81 tno: 25 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 26 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 27 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 28 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 29 vm count 120 == 120 for state any PASSED
# 67,89 tno: 30 vm count 120 == 120 for state any PASSED
# 67,96 tno: 31 vm count 120 == 120 for state any PASSED
# 67,105 tno: 32 vm count 120 == 120 for state any PASSED
# 69,160 tno: 33 vm: vm117 state provision == provision PASSED
# 69,160 tno: 34 vm: vm116 state provision == provision PASSED
# 69,160 tno: 35 vm: vm108 state provision == provision PASSED
# 69,160 tno: 36 vm: vm104 state provision == provision PASSED
# 69,160 tno: 37 vm: vm103 state provision == provision PASSED
# 69,160 tno: 38 vm: vm102 state provision == provision PASSED
# 69,160 tno: 39 vm: vm101 state provision == provision PASSED
# 69,160 tno: 40 vm: vm99 state provision == provision PASSED
# 69,160 tno: 41 vm: vm90 state provision == provision PASSED
# 70,129 tno: 42 vm count in s1 9 == 9 for state=provision PASSED
# 70,136 tno: 43 vm count in s1 9 == 9 for state=provision PASSED
# 71 tno: 44 Server ('s1', 16, 0) available < min vm 2 PASSED
# 65,68 tno: 45 server s2 with state idle found PASSED
# 65,75 tno: 46 server s2 with state idle found PASSED
# 66,81 tno: 47 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 48 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 49 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 50 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 51 vm count 120 == 120 for state any PASSED
# 67,89 tno: 52 vm count 120 == 120 for state any PASSED
# 67,96 tno: 53 vm count 120 == 120 for state any PASSED
# 67,105 tno: 54 vm count 120 == 120 for state any PASSED
# 69,160 tno: 55 vm: vm115 state provision == provision PASSED
# 69,160 tno: 56 vm: vm114 state provision == provision PASSED
# 69,160 tno: 57 vm: vm95 state provision == provision PASSED
# 69,160 tno: 58 vm: vm89 state provision == provision PASSED
# 69,160 tno: 59 vm: vm83 state provision == provision PASSED
# 70,129 tno: 60 vm count in s2 5 == 5 for state=provision PASSED
# 70,136 tno: 61 vm count in s2 5 == 5 for state=provision PASSED
# 71 tno: 62 Server ('s2', 22, 0) available < min vm 2 PASSED
# 65,68 tno: 63 server s3 with state idle found PASSED
# 65,75 tno: 64 server s3 with state idle found PASSED
# 66,81 tno: 65 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 66 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 67 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 68 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 69 vm count 120 == 120 for state any PASSED
# 67,89 tno: 70 vm count 120 == 120 for state any PASSED
# 67,96 tno: 71 vm count 120 == 120 for state any PASSED
# 67,105 tno: 72 vm count 120 == 120 for state any PASSED
# 69,160 tno: 73 vm: vm113 state provision == provision PASSED
# 69,160 tno: 74 vm: vm112 state provision == provision PASSED
# 69,160 tno: 75 vm: vm98 state provision == provision PASSED
# 69,160 tno: 76 vm: vm97 state provision == provision PASSED
# 69,160 tno: 77 vm: vm94 state provision == provision PASSED
# 69,160 tno: 78 vm: vm93 state provision == provision PASSED
# 69,160 tno: 79 vm: vm88 state provision == provision PASSED
# 69,160 tno: 80 vm: vm87 state provision == provision PASSED
# 69,160 tno: 81 vm: vm82 state provision == provision PASSED
# 69,160 tno: 82 vm: vm76 state provision == provision PASSED
# 70,129 tno: 83 vm count in s3 10 == 10 for state=provision PASSED
# 70,136 tno: 84 vm count in s3 10 == 10 for state=provision PASSED
# 71 tno: 85 Server ('s3', 20, 0) available < min vm 2 PASSED
# 65,68 tno: 86 server s4 with state idle found PASSED
# 65,75 tno: 87 server s4 with state idle found PASSED
# 66,81 tno: 88 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 89 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 90 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 91 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 92 vm count 120 == 120 for state any PASSED
# 67,89 tno: 93 vm count 120 == 120 for state any PASSED
# 67,96 tno: 94 vm count 120 == 120 for state any PASSED
# 67,105 tno: 95 vm count 120 == 120 for state any PASSED
# 69,160 tno: 96 vm: vm109 state provision == provision PASSED
# 69,160 tno: 97 vm: vm107 state provision == provision PASSED
# 69,160 tno: 98 vm: vm92 state provision == provision PASSED
# 69,160 tno: 99 vm: vm86 state provision == provision PASSED
# 69,160 tno: 100 vm: vm85 state provision == provision PASSED
# 69,160 tno: 101 vm: vm81 state provision == provision PASSED
# 69,160 tno: 102 vm: vm80 state provision == provision PASSED
# 69,160 tno: 103 vm: vm79 state provision == provision PASSED
# 69,160 tno: 104 vm: vm75 state provision == provision PASSED
# 69,160 tno: 105 vm: vm69 state provision == provision PASSED
# 69,160 tno: 106 vm: vm68 state provision == provision PASSED
# 70,129 tno: 107 vm count in s4 11 == 11 for state=provision PASSED
# 70,136 tno: 108 vm count in s4 11 == 11 for state=provision PASSED
# 71 tno: 109 Server ('s4', 18, 0) available < min vm 2 PASSED
# 65,68 tno: 110 server s5 with state idle found PASSED
# 65,75 tno: 111 server s5 with state idle found PASSED
# 66,81 tno: 112 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 113 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 114 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 115 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 116 vm count 120 == 120 for state any PASSED
# 67,89 tno: 117 vm count 120 == 120 for state any PASSED
# 67,96 tno: 118 vm count 120 == 120 for state any PASSED
# 67,105 tno: 119 vm count 120 == 120 for state any PASSED
# 69,160 tno: 120 vm: vm91 state provision == provision PASSED
# 69,160 tno: 121 vm: vm84 state provision == provision PASSED
# 69,160 tno: 122 vm: vm78 state provision == provision PASSED
# 69,160 tno: 123 vm: vm74 state provision == provision PASSED
# 69,160 tno: 124 vm: vm73 state provision == provision PASSED
# 69,160 tno: 125 vm: vm72 state provision == provision PASSED
# 69,160 tno: 126 vm: vm71 state provision == provision PASSED
# 69,160 tno: 127 vm: vm67 state provision == provision PASSED
# 69,160 tno: 128 vm: vm66 state provision == provision PASSED
# 69,160 tno: 129 vm: vm65 state provision == provision PASSED
# 69,160 tno: 130 vm: vm64 state provision == provision PASSED
# 69,160 tno: 131 vm: vm62 state provision == provision PASSED
# 69,160 tno: 132 vm: vm55 state provision == provision PASSED
# 70,129 tno: 133 vm count in s5 13 == 13 for state=provision PASSED
# 70,136 tno: 134 vm count in s5 13 == 13 for state=provision PASSED
# 71 tno: 135 Server ('s5', 16, 0) available < min vm 2 PASSED
# 65,68 tno: 136 server s6 with state idle found PASSED
# 65,75 tno: 137 server s6 with state idle found PASSED
# 66,81 tno: 138 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 139 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 140 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 141 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 142 vm count 120 == 120 for state any PASSED
# 67,89 tno: 143 vm count 120 == 120 for state any PASSED
# 67,96 tno: 144 vm count 120 == 120 for state any PASSED
# 67,105 tno: 145 vm count 120 == 120 for state any PASSED
# 69,160 tno: 146 vm: vm77 state provision == provision PASSED
# 69,160 tno: 147 vm: vm70 state provision == provision PASSED
# 69,160 tno: 148 vm: vm61 state provision == provision PASSED
# 69,160 tno: 149 vm: vm60 state provision == provision PASSED
# 69,160 tno: 150 vm: vm59 state provision == provision PASSED
# 69,160 tno: 151 vm: vm58 state provision == provision PASSED
# 69,160 tno: 152 vm: vm54 state provision == provision PASSED
# 69,160 tno: 153 vm: vm53 state provision == provision PASSED
# 69,160 tno: 154 vm: vm52 state provision == provision PASSED
# 69,160 tno: 155 vm: vm48 state provision == provision PASSED
# 69,160 tno: 156 vm: vm47 state provision == provision PASSED
# 70,129 tno: 157 vm count in s6 11 == 11 for state=provision PASSED
# 70,136 tno: 158 vm count in s6 11 == 11 for state=provision PASSED
# 71 tno: 159 Server ('s6', 22, 0) available < min vm 2 PASSED
# 65,68 tno: 160 server s7 with state idle found PASSED
# 65,75 tno: 161 server s7 with state idle found PASSED
# 66,81 tno: 162 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 163 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 164 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 165 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 166 vm count 120 == 120 for state any PASSED
# 67,89 tno: 167 vm count 120 == 120 for state any PASSED
# 67,96 tno: 168 vm count 120 == 120 for state any PASSED
# 67,105 tno: 169 vm count 120 == 120 for state any PASSED
# 69,160 tno: 170 vm: vm63 state provision == provision PASSED
# 69,160 tno: 171 vm: vm57 state provision == provision PASSED
# 69,160 tno: 172 vm: vm56 state provision == provision PASSED
# 69,160 tno: 173 vm: vm51 state provision == provision PASSED
# 69,160 tno: 174 vm: vm46 state provision == provision PASSED
# 69,160 tno: 175 vm: vm45 state provision == provision PASSED
# 69,160 tno: 176 vm: vm41 state provision == provision PASSED
# 69,160 tno: 177 vm: vm40 state provision == provision PASSED
# 69,160 tno: 178 vm: vm39 state provision == provision PASSED
# 69,160 tno: 179 vm: vm34 state provision == provision PASSED
# 69,160 tno: 180 vm: vm33 state provision == provision PASSED
# 70,129 tno: 181 vm count in s7 11 == 11 for state=provision PASSED
# 70,136 tno: 182 vm count in s7 11 == 11 for state=provision PASSED
# 71 tno: 183 Server ('s7', 20, 0) available < min vm 2 PASSED
# 65,68 tno: 184 server s8 with state idle found PASSED
# 65,75 tno: 185 server s8 with state idle found PASSED
# 66,81 tno: 186 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 187 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 188 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 189 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 190 vm count 120 == 120 for state any PASSED
# 67,89 tno: 191 vm count 120 == 120 for state any PASSED
# 67,96 tno: 192 vm count 120 == 120 for state any PASSED
# 67,105 tno: 193 vm count 120 == 120 for state any PASSED
# 69,160 tno: 194 vm: vm50 state provision == provision PASSED
# 69,160 tno: 195 vm: vm49 state provision == provision PASSED
# 69,160 tno: 196 vm: vm44 state provision == provision PASSED
# 69,160 tno: 197 vm: vm43 state provision == provision PASSED
# 69,160 tno: 198 vm: vm42 state provision == provision PASSED
# 69,160 tno: 199 vm: vm38 state provision == provision PASSED
# 69,160 tno: 200 vm: vm37 state provision == provision PASSED
# 69,160 tno: 201 vm: vm32 state provision == provision PASSED
# 69,160 tno: 202 vm: vm31 state provision == provision PASSED
# 69,160 tno: 203 vm: vm30 state provision == provision PASSED
# 69,160 tno: 204 vm: vm27 state provision == provision PASSED
# 69,160 tno: 205 vm: vm26 state provision == provision PASSED
# 69,160 tno: 206 vm: vm25 state provision == provision PASSED
# 69,160 tno: 207 vm: vm24 state provision == provision PASSED
# 69,160 tno: 208 vm: vm20 state provision == provision PASSED
# 69,160 tno: 209 vm: vm19 state provision == provision PASSED
# 70,129 tno: 210 vm count in s8 16 == 16 for state=provision PASSED
# 70,136 tno: 211 vm count in s8 16 == 16 for state=provision PASSED
# 71 tno: 212 Server ('s8', 18, 0) available < min vm 2 PASSED
# 65,68 tno: 213 server s9 with state idle found PASSED
# 65,75 tno: 214 server s9 with state idle found PASSED
# 66,81 tno: 215 vm count 120 == 120 for state provision PASSED
# 66,89 tno: 216 vm count 120 == 120 for state provision PASSED
# 66,96 tno: 217 vm count 120 == 120 for state provision PASSED
# 66,105 tno: 218 vm count 120 == 120 for state provision PASSED
# 67,81 tno: 219 vm count 120 == 120 for state any PASSED
# 67,89 tno: 220 vm count 120 == 120 for state any PASSED
# 67,96 tno: 221 vm count 120 == 120 for state any PASSED
# 67,105 tno: 222 vm count 120 == 120 for state any PASSED
# 69,160 tno: 223 vm: vm36 state provision == provision PASSED
# 69,160 tno: 224 vm: vm35 state provision == provision PASSED
# 69,160 tno: 225 vm: vm29 state provision == provision PASSED
# 69,160 tno: 226 vm: vm28 state provision == provision PASSED
# 69,160 tno: 227 vm: vm23 state provision == provision PASSED
# 69,160 tno: 228 vm: vm22 state provision == provision PASSED
# 69,160 tno: 229 vm: vm21 state provision == provision PASSED
# 69,160 tno: 230 vm: vm18 state provision == provision PASSED
# 69,160 tno: 231 vm: vm17 state provision == provision PASSED
# 69,160 tno: 232 vm: vm16 state provision == provision PASSED
# 69,160 tno: 233 vm: vm15 state provision == provision PASSED
# 69,160 tno: 234 vm: vm14 state provision == provision PASSED
# 69,160 tno: 235 vm: vm13 state provision == provision PASSED
# 69,160 tno: 236 vm: vm12 state provision == provision PASSED
# 69,160 tno: 237 vm: vm11 state provision == provision PASSED
# 69,160 tno: 238 vm: vm10 state provision == provision PASSED
# 69,160 tno: 239 vm: vm9 state provision == provision PASSED
# 69,160 tno: 240 vm: vm8 state provision == provision PASSED
# 69,160 tno: 241 vm: vm7 state provision == provision PASSED
# 69,160 tno: 242 vm: vm6 state provision == provision PASSED
# 69,160 tno: 243 vm: vm5 state provision == provision PASSED
# 69,160 tno: 244 vm: vm4 state provision == provision PASSED
# 69,160 tno: 245 vm: vm3 state provision == provision PASSED
# 69,160 tno: 246 vm: vm2 state provision == provision PASSED
# 69,160 tno: 247 vm: vm1 state provision == provision PASSED
# 69,160 tno: 248 vm: vm0 state provision == provision PASSED
# 70,129 tno: 249 vm count in s9 26 == 26 for state=provision PASSED
# 70,136 tno: 250 vm count in s9 26 == 26 for state=provision PASSED
# 71 tno: 251 Server ('s9', 4, 0) available < min vm 2 PASSED
# vm119 2 4 s0
# vm118 2 4 s0
# vm117 2 4 s1
# vm116 2 4 s1
# vm115 2 4 s2
# vm114 2 4 s2
# vm113 2 4 s3
# vm112 2 4 s3
# vm111 4 16 s0
# vm110 4 16 s0
# 77,41 tno: 252 crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=110, vprovision=110, vactive=0, vidle=0, vdeleted=10) == crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=110, vprovision=110, vactive=0, vidle=0, vdeleted=10) PASSED
# 84,171 tno: 253 vm vm119 not present PASSED
# 84,179 tno: 254 vm vm119 not present PASSED
# 85 tno: 255 vm vm119 state deleted == deleted PASSED
# 84,171 tno: 256 vm vm118 not present PASSED
# 84,179 tno: 257 vm vm118 not present PASSED
# 85 tno: 258 vm vm118 state deleted == deleted PASSED
# 84,171 tno: 259 vm vm117 not present PASSED
# 84,179 tno: 260 vm vm117 not present PASSED
# 85 tno: 261 vm vm117 state deleted == deleted PASSED
# 84,171 tno: 262 vm vm116 not present PASSED
# 84,179 tno: 263 vm vm116 not present PASSED
# 85 tno: 264 vm vm116 state deleted == deleted PASSED
# 84,171 tno: 265 vm vm115 not present PASSED
# 84,179 tno: 266 vm vm115 not present PASSED
# 85 tno: 267 vm vm115 state deleted == deleted PASSED
# 84,171 tno: 268 vm vm114 not present PASSED
# 84,179 tno: 269 vm vm114 not present PASSED
# 85 tno: 270 vm vm114 state deleted == deleted PASSED
# 84,171 tno: 271 vm vm113 not present PASSED
# 84,179 tno: 272 vm vm113 not present PASSED
# 85 tno: 273 vm vm113 state deleted == deleted PASSED
# 84,171 tno: 274 vm vm112 not present PASSED
# 84,179 tno: 275 vm vm112 not present PASSED
# 85 tno: 276 vm vm112 state deleted == deleted PASSED
# 84,171 tno: 277 vm vm111 not present PASSED
# 84,179 tno: 278 vm vm111 not present PASSED
# 85 tno: 279 vm vm111 state deleted == deleted PASSED
# 84,171 tno: 280 vm vm110 not present PASSED
# 84,179 tno: 281 vm vm110 not present PASSED
# 85 tno: 282 vm vm110 state deleted == deleted PASSED
# recreating vm110
# recreating vm111
# recreating vm112
# recreating vm113
# recreating vm114
# recreating vm115
# recreating vm116
# recreating vm117
# recreating vm118
# recreating vm119
# 94,41 tno: 283 crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=120, vprovision=120, vactive=0, vidle=0, vdeleted=10) == crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=120, vprovision=120, vactive=0, vidle=0, vdeleted=10) PASSED
# 120
# provisioning failed for ('vm120', 1, 1)
# Provisioned total of 120 more vms
# [sconf(name='s9', ncpu=4, mem=0), sconf(name='s8', ncpu=18, mem=0), sconf(name='s7', ncpu=20, mem=0), sconf(name='s6', ncpu=22, mem=0), sconf(name='s5', ncpu=16, mem=0), sconf(name='s4', ncpu=18, mem=0), sconf(name='s3', ncpu=20, mem=0), sconf(name='s2', ncpu=22, mem=0), sconf(name='s1', ncpu=16, mem=0), sconf(name='s0', ncpu=18, mem=0)]
# allocated:aggr(ncpu=3576, mem=28000) Total: aggr(ncpu=3750, mem=28000) available:aggr(ncpu=174, mem=0)
# 125,41 tno: 284 crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=120, vprovision=120, vactive=0, vidle=0, vdeleted=10) == crm_stat(stotal=10, sidle=10, sactive=0, sfail=0, sdeleted=0, vtotal=120, vprovision=120, vactive=0, vidle=0, vdeleted=10) PASSED
# 130,41 tno: 285 crm_stat(stotal=10, sidle=0, sactive=10, sfail=0, sdeleted=0, vtotal=120, vprovision=0, vactive=120, vidle=0, vdeleted=10) == crm_stat(stotal=10, sidle=0, sactive=10, sfail=0, sdeleted=0, vtotal=120, vprovision=0, vactive=120, vidle=0, vdeleted=10) PASSED
# server: s0
# server: s1
# server: s2
# server: s3
# server: s4
# server: s5
# server: s6
# server: s7
# server: s8
# server: s9
# Failing few servers
# 140,41 tno: 286 crm_stat(stotal=10, sidle=0, sactive=8, sfail=2, sdeleted=0, vtotal=120, vprovision=0, vactive=103, vidle=17, vdeleted=10) == crm_stat(stotal=10, sidle=0, sactive=8, sfail=2, sdeleted=0, vtotal=120, vprovision=0, vactive=103, vidle=17, vdeleted=10) PASSED
# 142 tno: 287 idlevms count17 match 17 vms in failed servers PASSED
# Deleting few servers
# Deleting few servers
# 151,41 tno: 288 crm_stat(stotal=8, sidle=0, sactive=8, sfail=0, sdeleted=2, vtotal=120, vprovision=0, vactive=103, vidle=17, vdeleted=10) == crm_stat(stotal=8, sidle=0, sactive=8, sfail=0, sdeleted=2, vtotal=120, vprovision=0, vactive=103, vidle=17, vdeleted=10) PASSED
# deleting 10 vms
# deleting vm117
# 167,41 tno: 289 crm_stat(stotal=8, sidle=0, sactive=8, sfail=0, sdeleted=2, vtotal=110, vprovision=0, vactive=94, vidle=16, vdeleted=20) == crm_stat(stotal=8, sidle=0, sactive=8, sfail=0, sdeleted=2, vtotal=110, vprovision=0, vactive=94, vidle=16, vdeleted=20) PASSED

# %%
for s in crm.server_list:
    for v in s.vl:
        print(v.name,v.state,s.name,s.state,v.acpu,v.amem)
# Out:
# vm36 active s9 active 4 16
# vm35 active s9 active 2 4
# vm29 active s9 active 4 16
# vm28 active s9 active 2 4
# vm23 active s9 active 8 64
# vm22 active s9 active 4 16
# vm21 active s9 active 2 4
# vm18 active s9 active 32 256
# vm17 active s9 active 16 128
# vm16 active s9 active 8 64
# vm15 active s9 active 4 16
# vm14 active s9 active 2 4
# vm13 active s9 active 128 1024
# vm12 active s9 active 64 512
# vm11 active s9 active 32 256
# vm10 active s9 active 16 128
# vm9 active s9 active 8 64
# vm8 deleted s9 active 4 16
# vm7 deleted s9 active 2 4
# vm6 deleted s9 active 128 1024
# vm5 deleted s9 active 64 512
# vm4 deleted s9 active 32 256
# vm3 deleted s9 active 16 128
# vm2 deleted s9 active 8 64
# vm1 deleted s9 active 4 16
# vm0 deleted s9 active 2 4
# vm50 active s8 active 4 16
# vm49 active s8 active 2 4
# vm44 active s8 active 8 64
# vm43 active s8 active 4 16
# vm42 active s8 active 2 4
# vm38 active s8 active 16 128
# vm37 active s8 active 8 64
# vm32 active s8 active 32 256
# vm31 active s8 active 16 128
# vm30 active s8 active 8 64
# vm27 active s8 active 128 1024
# vm26 active s8 active 64 512
# vm25 active s8 active 32 256
# vm24 active s8 active 16 128
# vm20 active s8 active 128 1024
# vm19 active s8 active 64 512
# vm63 active s7 active 2 4
# vm57 active s7 active 4 16
# vm56 active s7 active 2 4
# vm51 active s7 active 8 64
# vm46 active s7 active 32 256
# vm45 active s7 active 16 128
# vm41 active s7 active 128 1024
# vm40 active s7 active 64 512
# vm39 active s7 active 32 256
# vm34 active s7 active 128 1024
# vm33 active s7 active 64 512
# vm77 active s6 active 2 4
# vm70 active s6 active 2 4
# vm61 active s6 active 64 512
# vm60 active s6 active 32 256
# vm59 active s6 active 16 128
# vm58 active s6 active 8 64
# vm54 active s6 active 64 512
# vm53 active s6 active 32 256
# vm52 active s6 active 16 128
# vm48 active s6 active 128 1024
# vm47 active s6 active 64 512
# vm91 active s5 active 2 4
# vm84 active s5 active 2 4
# vm78 active s5 active 4 16
# vm74 active s5 active 32 256
# vm73 active s5 active 16 128
# vm72 active s5 active 8 64
# vm71 active s5 active 4 16
# vm67 active s5 active 32 256
# vm66 active s5 active 16 128
# vm65 active s5 active 8 64
# vm64 active s5 active 4 16
# vm62 active s5 active 128 1024
# vm55 active s5 active 128 1024
# vm109 active s4 active 2 4
# vm107 active s4 active 2 4
# vm92 active s4 active 4 16
# vm86 active s4 active 8 64
# vm85 active s4 active 4 16
# vm81 active s4 active 32 256
# vm80 active s4 active 16 128
# vm79 active s4 active 8 64
# vm75 active s4 active 64 512
# vm69 active s4 active 128 1024
# vm68 active s4 active 64 512
# vm113 active s3 active 2 4
# vm112 active s3 active 2 4
# vm113 deleted s3 active 2 4
# vm112 deleted s3 active 2 4
# vm98 active s3 active 8 64
# vm97 active s3 active 4 16
# vm94 active s3 active 16 128
# vm93 active s3 active 8 64
# vm88 active s3 active 32 256
# vm87 active s3 active 16 128
# vm82 active s3 active 64 512
# vm76 active s3 active 128 1024
# vm115 active s2 active 2 4
# vm114 active s2 active 2 4
# vm115 deleted s2 active 2 4
# vm114 deleted s2 active 2 4
# vm95 active s2 active 32 256
# vm89 active s2 active 64 512
# vm83 active s2 active 128 1024
# vm117 deleted s1 deleted 2 4
# vm116 idle s1 deleted 2 4
# vm117 deleted s1 deleted 2 4
# vm116 deleted s1 deleted 2 4
# vm108 idle s1 deleted 4 16
# vm104 idle s1 deleted 4 16
# vm103 idle s1 deleted 16 128
# vm102 idle s1 deleted 8 64
# vm101 idle s1 deleted 4 16
# vm99 idle s1 deleted 16 128
# vm90 idle s1 deleted 128 1024
# vm119 idle s0 deleted 2 4
# vm118 idle s0 deleted 2 4
# vm111 idle s0 deleted 4 16
# vm110 idle s0 deleted 4 16
# vm119 deleted s0 deleted 2 4
# vm118 deleted s0 deleted 2 4
# vm111 deleted s0 deleted 4 16
# vm110 deleted s0 deleted 4 16
# vm106 idle s0 deleted 16 128
# vm105 idle s0 deleted 8 64
# vm100 idle s0 deleted 32 256
# vm96 idle s0 deleted 64 512

# %%
for s in crm.server_list:
    print(s.name,s.acpu,s.amem,s.nvms)
# Out:
# s9 264 2024 35
# s8 18 0 16
# s7 20 0 11
# s6 22 0 11
# s5 16 0 13
# s4 18 0 11
# s3 20 0 10
# s2 22 0 5
# s1 18 4 10
# s0 18 0 8

# %%
#now reprovision the idle vms in those 10 vm slots.
c=crm.provision_all_idle_vms()
print(f'idle vms reprovisioned is {c}')
check_stat(crm_stat(stotal=nservers-2,sidle=0,sactive=nservers-2,sfail=0,sdeleted=2,vtotal=len(vms)-10,vprovision=0,vactive=len(vms)-nvms-10+c,vidle=nvms-c, vdeleted=20))
# Out:
# idle vms reprovisioned is 9
# 4,41 tno: 290 crm_stat(stotal=8, sidle=0, sactive=8, sfail=0, sdeleted=2, vtotal=110, vprovision=0, vactive=103, vidle=7, vdeleted=20) == crm_stat(stotal=8, sidle=0, sactive=8, sfail=0, sdeleted=2, vtotal=110, vprovision=0, vactive=103, vidle=7, vdeleted=20) PASSED

# %%
for s in crm.server_list:
    for v in s.vl:
        print(v.name,v.state,s.name,s.state,v.acpu,v.amem)
# Out:
# vm90 active s9 active 128 1024
# vm119 active s9 active 2 4
# vm118 active s9 active 2 4
# vm111 active s9 active 4 16
# vm110 active s9 active 4 16
# vm106 active s9 active 16 128
# vm105 active s9 active 8 64
# vm100 active s9 active 32 256
# vm96 active s9 active 64 512
# vm36 active s9 active 4 16
# vm35 active s9 active 2 4
# vm29 active s9 active 4 16
# vm28 active s9 active 2 4
# vm23 active s9 active 8 64
# vm22 active s9 active 4 16
# vm21 active s9 active 2 4
# vm18 active s9 active 32 256
# vm17 active s9 active 16 128
# vm16 active s9 active 8 64
# vm15 active s9 active 4 16
# vm14 active s9 active 2 4
# vm13 active s9 active 128 1024
# vm12 active s9 active 64 512
# vm11 active s9 active 32 256
# vm10 active s9 active 16 128
# vm9 active s9 active 8 64
# vm8 deleted s9 active 4 16
# vm7 deleted s9 active 2 4
# vm6 deleted s9 active 128 1024
# vm5 deleted s9 active 64 512
# vm4 deleted s9 active 32 256
# vm3 deleted s9 active 16 128
# vm2 deleted s9 active 8 64
# vm1 deleted s9 active 4 16
# vm0 deleted s9 active 2 4
# vm50 active s8 active 4 16
# vm49 active s8 active 2 4
# vm44 active s8 active 8 64
# vm43 active s8 active 4 16
# vm42 active s8 active 2 4
# vm38 active s8 active 16 128
# vm37 active s8 active 8 64
# vm32 active s8 active 32 256
# vm31 active s8 active 16 128
# vm30 active s8 active 8 64
# vm27 active s8 active 128 1024
# vm26 active s8 active 64 512
# vm25 active s8 active 32 256
# vm24 active s8 active 16 128
# vm20 active s8 active 128 1024
# vm19 active s8 active 64 512
# vm63 active s7 active 2 4
# vm57 active s7 active 4 16
# vm56 active s7 active 2 4
# vm51 active s7 active 8 64
# vm46 active s7 active 32 256
# vm45 active s7 active 16 128
# vm41 active s7 active 128 1024
# vm40 active s7 active 64 512
# vm39 active s7 active 32 256
# vm34 active s7 active 128 1024
# vm33 active s7 active 64 512
# vm77 active s6 active 2 4
# vm70 active s6 active 2 4
# vm61 active s6 active 64 512
# vm60 active s6 active 32 256
# vm59 active s6 active 16 128
# vm58 active s6 active 8 64
# vm54 active s6 active 64 512
# vm53 active s6 active 32 256
# vm52 active s6 active 16 128
# vm48 active s6 active 128 1024
# vm47 active s6 active 64 512
# vm91 active s5 active 2 4
# vm84 active s5 active 2 4
# vm78 active s5 active 4 16
# vm74 active s5 active 32 256
# vm73 active s5 active 16 128
# vm72 active s5 active 8 64
# vm71 active s5 active 4 16
# vm67 active s5 active 32 256
# vm66 active s5 active 16 128
# vm65 active s5 active 8 64
# vm64 active s5 active 4 16
# vm62 active s5 active 128 1024
# vm55 active s5 active 128 1024
# vm109 active s4 active 2 4
# vm107 active s4 active 2 4
# vm92 active s4 active 4 16
# vm86 active s4 active 8 64
# vm85 active s4 active 4 16
# vm81 active s4 active 32 256
# vm80 active s4 active 16 128
# vm79 active s4 active 8 64
# vm75 active s4 active 64 512
# vm69 active s4 active 128 1024
# vm68 active s4 active 64 512
# vm113 active s3 active 2 4
# vm112 active s3 active 2 4
# vm113 deleted s3 active 2 4
# vm112 deleted s3 active 2 4
# vm98 active s3 active 8 64
# vm97 active s3 active 4 16
# vm94 active s3 active 16 128
# vm93 active s3 active 8 64
# vm88 active s3 active 32 256
# vm87 active s3 active 16 128
# vm82 active s3 active 64 512
# vm76 active s3 active 128 1024
# vm115 active s2 active 2 4
# vm114 active s2 active 2 4
# vm115 deleted s2 active 2 4
# vm114 deleted s2 active 2 4
# vm95 active s2 active 32 256
# vm89 active s2 active 64 512
# vm83 active s2 active 128 1024
# vm117 deleted s1 deleted 2 4
# vm116 idle s1 deleted 2 4
# vm117 deleted s1 deleted 2 4
# vm116 deleted s1 deleted 2 4
# vm108 idle s1 deleted 4 16
# vm104 idle s1 deleted 4 16
# vm103 idle s1 deleted 16 128
# vm102 idle s1 deleted 8 64
# vm101 idle s1 deleted 4 16
# vm99 idle s1 deleted 16 128
# vm90 active s1 deleted 128 1024
# vm119 active s0 deleted 2 4
# vm118 active s0 deleted 2 4
# vm111 active s0 deleted 4 16
# vm110 active s0 deleted 4 16
# vm119 deleted s0 deleted 2 4
# vm118 deleted s0 deleted 2 4
# vm111 deleted s0 deleted 4 16
# vm110 deleted s0 deleted 4 16
# vm106 active s0 deleted 16 128
# vm105 active s0 deleted 8 64
# vm100 active s0 deleted 32 256
# vm96 active s0 deleted 64 512

# %%
for i in crm.unprovisioned:
    print(i.name,i.amem,i.acpu)
# Out:
# vm116 4 2
# vm108 16 4
# vm104 16 4
# vm103 128 16
# vm102 64 8
# vm101 16 4
# vm99 128 16

# %%
for s in crm.server_list:
    print(s.name,s.state,s.acpu,s.amem)

# %%
dfskgl

# %%
# add the servers back
vm=crm.get_vms('idle')
for v in vm:
    print(f'idlevm: {v.vc}')
print(f'Adding server config {ps[0].sc}')
a=crm.add(ps[0].sc.name, ps[0].sc.ncpu, ps[0].sc.mem)
ps[0]=a
print(f'adding provisioned {a.nvms} vms')
check_stat(crm_stat(stotal=nservers-1,sidle=1,sactive=nservers-2,sfail=0,sdeleted=2,vtotal=len(vms)-10,vprovision=0,vactive=len(vms)-nvms-10+c,vidle=nvms-c, vdeleted=20))

print(f'Adding server config {ps[1].sc}')
a=crm.add(ps[1].sc.name, ps[1].sc.ncpu, ps[1].sc.mem)
ps[1]=a
print(f'adding provisioned {a.nvms} vms')
check_stat(crm_stat(stotal=nservers,sidle=1,sactive=nservers-1,sfail=0,sdeleted=2,vtotal=len(vms)-10,vprovision=0,vactive=len(vms)-nvms-10+c+1,vidle=nvms-c-1, vdeleted=20))

# fail and unfail the servers. all vms should be provisioned exactly as before.

nvms1=ps[7].nvms
print(f'Failing server {ps[7].sc} nvms1 idle: {nvms1}')
crm.fail(ps[7].sc.name)
check_stat(crm_stat(stotal=nservers,sidle=1,sactive=nservers-2,sfail=1,sdeleted=2,vtotal=len(vms)-10,vprovision=0,vactive=len(vms)-nvms-10+c+1-nvms1,vidle=nvms-c-1+nvms1, vdeleted=20))
print(f'UnFailing server {ps[7].sc} nvms1 idle: {nvms1}')
crm.unfail(ps[7].sc.name)
pvms1=ps[7].nvms
if pvms1 != nvms1:
    print(f'fail/unfail did not reprovision all idle vms')
    print(f'faill vms: {nvms} reprovision vms: {pvms1}')
check_stat(crm_stat(stotal=nservers,sidle=1,sactive=nservers-1,sfail=0,sdeleted=2,vtotal=len(vms)-10,vprovision=0,vactive=len(vms)-nvms-10+c+1,vidle=nvms-c-1, vdeleted=20))

# now delete all physical servers

for p in ps:
    print(f'server: {p.sc.name}')

for p in ps:
    print(f'deleting {p.sc.name}')
    if p.nvms:
        te=0
        try:
            crm.delete_server(p.sc.name)
        except Exception as e:
            te=1
        s=f'active server {p.sc.name} should fail'
        mycheck(te==1, s)

# now delete all vms

#    for v in crm.get_vms('any'):
#        print(v.vc.name)
for v in vms:
    try:
        crm.delete_vm(v.vc.name)
    except Exception as e:
        s=f'Delete_vm returned exception for {v.vc}'
        print(e)

# check for zero vms
check_stat(crm_stat(stotal=nservers,sidle=nservers,sactive=0,sfail=0,sdeleted=2,vtotal=0,vprovision=0,vactive=0,vidle=0, vdeleted=130))

#delete all physical servers
for p in ps:
    print(f'deleting {p.sc.name}')
    mycheck(p.nvms==0, f'Server {p.sc} should have zero vms. Found {p.nvms}')
    try:
        crm.delete_server(p.sc.name)
    except Exception as e:
        s=f'Idle server {p.sc.name} can be deleted'
        mycheck(0, s)

check_stat(crm_stat(stotal=0,sidle=0,sactive=0,sfail=0,sdeleted=12,vtotal=0,vprovision=0,vactive=0,vidle=0, vdeleted=130))

# %% [markdown]
# ## Crm test

# %%
global crm
crm=mycrm()
a = crm.add("s1", 500, 1000)
print(a.sc)
check_server_count(1, 'any')
s=crm.get_servers('any')
mycheck((len(s) == 1), "get servers should return one entry")
check_server_count(1, 'idle')
check_server_state('s1', 'idle')
s=crm.get_stat()
check_stat(crm_stat(stotal=1,sidle=1))
crm.fail(a.sc.name)
check_stat(crm_stat(stotal=1,sfail=1))
check_server_state('s1', 'fail')
crm.unfail(a.sc.name)
check_stat(crm_stat(stotal=1,sidle=1))
check_server_state('s1', 'idle')
crm.delete_server(a.sc.name)
check_stat(crm_stat(sdeleted=1))
check_server_count(0, 'any')

print(f'*********crm_1server tests done *********')
print(f'*********crm_1server tests done *********')

# %% [markdown]
# # CRMVM test

# %%
import os
import sys
from mylist import *
from mycrm import *
from myserver import *
from myvm import *
from inspect import currentframe, getframeinfo

# test.py for toy cloud assignment.
# feel free to comment the relevant parts in main function.

## test helper functions

global test_no
global crm
test_no=0
def mycheck(result, msg, lno=0):
    global test_no
    test_no += 1
    cf=currentframe()
    l1=cf.f_back.f_lineno
    if lno:
        l=f'{lno},{l1}'
    else:
        l=f'{l1}'
    if result:
        print(f'{l} tno: {test_no} {msg} PASSED ')
    else:
        print(f'{l}: tno: {test_no} {msg} FAILED ')
        sys.exit(1)

# template crmstat to copy and change values.
#mys=crm_stat(stotal=1,sidle=1,sactive=0,sfail=0,vtotal=1,vprovision=1,vactive=0,'vidle', vdeleted=0)
#print(mys)


def check_stat(s1):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_stat()
    mycheck((s==s1),f'{s1} == {s}', lno)

def check_server_count(count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_servers(state)
    mycheck(len(s) == count, f'server_count {len(s)} == {count} for state {state}', lno)

    s=crm.get_servers('any')
    c=0
    for i in s:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c == count, f'server_count {c} == {count} for state {state}', lno)

def check_server_state(sname, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    assert(state != 'any')
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sname and i.state == state:
            f=1
            break
    mycheck(f==1, f'server {sname} with state {state} found', lno)
    s=crm.get_servers(state)
    f=0
    for i in s:
        if i.sc.name == sname and i.state == state:
            f=1
            break
    mycheck(f==1, f'server {sname} with state {state} found', lno)

def check_vm_count(count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_vms(state)
    mycheck(len(s) == count, f'vm count {len(s)} == {count} for state {state}', lno)

    s=crm.get_vms('any')
    c=0
    for i in s:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms(state)
        for j in v:
            c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms('any')
        for j in v:
            if state != 'any' and j.state != state:
                continue
            c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)



def check_server_vm_count(sr, count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=fs.get_vms('any')
    c=0
    for i in v:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c==count, f'vm count in {sr} {c} == {count} for state={state}', lno) 
    if state == 'any':
        return
    v=fs.get_vms(state)
    c=0
    for i in v:
        c += 1
    mycheck(c==count, f'vm count in {sr} {c} == {count} for state={state}', lno) 

def check_server_vm_state(sr, vm, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)
    v=crm.get_vms('any')
    f=0
    for i in v:
        if i.vc.name == vm:
            f=1
            fv=i
            break
    if f != 1:
        mycheck(0, f'vm {vm} in {sr} lookup', lno)
    mycheck(fv.state==state, f'vm: {fv.vc.name} state {fv.state} == {state}', lno) 

def check_novm(vm):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_vms('any')
    c=0
    for i in s:
        if i.vc.name == vm:
            c += 1
    mycheck(c == 0, f'vm {vm} not present', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms('any')
        for j in v:
            print(j.vc.name,j.state)
            if j.vc.name == vm:
                c += 1
    mycheck(c == 0, f'vm {vm} not present', lno)

def check_server_novm(sr, vm):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=crm.get_vms('any')
    f=0
    for i in v:
        if i.vc.name == vm:
            f=1
            fv=i
            break
    mycheck(f==0, f'vm: {vm}  in server {sr} not present', lno) 

global crm
crm=mycrm()
a = crm.add("s1", 500, 1000)
print(a)
check_server_state("s1", 'idle')
v=crm.provision_vm("vm1", 2, 50)
print(v)
check_server_state("s1", 'idle')
check_stat(crm_stat(stotal=1,sidle=1,vtotal=1,vprovision=1))
check_vm_count(1, 'provision')
check_vm_count(1, 'any')
check_server_vm_state("s1", "vm1", 'provision')
check_server_vm_count("s1", 1, 'provision')
crm.commit_provisioned_vms()
check_server_state("s1", 'active')
check_server_vm_count("s1", 1, 'active')
check_server_vm_state("s1", "vm1", 'active')
check_stat(crm_stat(stotal=1,sactive=1,vtotal=1,vactive=1))
check_vm_count(1, 'any')
check_vm_count(1, 'active')
te=0
try:
    crm.delete_server("s1")
except Exception as e:
    te=1
mycheck(te == 1, 'Cannot delete an active server')

# provision one more vm and then undo it.
v=crm.provision_vm("vm2", 2, 50)
print(v)
check_stat(crm_stat(stotal=1,sactive=1,vtotal=2,vprovision=1,vactive=1))
check_vm_count(2, 'any')
check_vm_count(1, 'active')
check_vm_count(1, 'provision')
check_server_vm_count("s1", 1, 'active')
check_server_vm_state("s1", "vm1", 'active')
check_server_vm_count("s1", 1, 'provision')
check_server_vm_state("s1", "vm2", 'provision')

# %%
for i in crm.get_vms('any'):
    print(i.name,i.state)

# %%
crm.provision_undo(1)
check_stat(crm_stat(stotal=1,sactive=1,vtotal=1,vactive=1,vdeleted=1))

# %%
for i in crm.get_vms('any'):
    print(i.name,i.state)

# %%
check_vm_count(1, 'any')

# %%
for i in crm.get_vms('any'):
    print(i.name,i.state)

# %%
count=1
state='any'

cf=currentframe()
lno=cf.f_back.f_lineno
s=crm.get_vms(state)
mycheck(len(s) == count, f'vm count {len(s)} == {count} for state {state}', lno)

s=crm.get_vms('any')
c=0
for i in s:
    if state != 'any' and i.state != state:
        continue
    c += 1
mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
c=0
s=crm.get_servers('any')
for i in s:
    v=i.get_vms(state)
    for j in v:
        c += 1
mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
c=0
s=crm.get_servers('any')
for i in s:
    v=i.get_vms('any')
    for j in v:
        if state != 'any' and j.state != state:
            continue
        c += 1
mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)

# %%
check_server_vm_count("s1", 1, 'any')
check_server_vm_count("s1", 1, 'active')
check_novm("vm2")
check_server_novm("s1", "vm2")
te=0
try:
    crm.delete_vm('random')
except Exception as e:
    te=1
mycheck(te == 1, 'Wrong name to delete')
crm.delete_vm("vm1")
check_vm_count(0, 'any')
check_server_vm_count("s1", 0, 'any')
check_novm("vm1")
check_server_novm("s1", "vm1")
check_stat(crm_stat(stotal=1,sidle=1,vdeleted=2))
crm.delete_server(a.sc.name)
check_stat(crm_stat(vdeleted=2,sdeleted=1))
check_server_count(0, 'any')
check_vm_count(0, 'any')
print(f'********crm_1vm tests done ************')
print(f'********crm_1vm tests done ************')

# %% [markdown]
# # VM Test

# %%
import sys
from mylist import *
from mycrm import *
from myserver import *
from myvm import *

from inspect import currentframe, getframeinfo

# test.py for toy cloud assignment.
# feel free to comment the relevant parts in main function.

## test helper functions

global test_no
global crm
test_no=0
def mycheck(result, msg, lno=0):
    global test_no
    test_no += 1
    cf=currentframe()
    l1=cf.f_back.f_lineno
    if lno:
        l=f'{lno},{l1}'
    else:
        l=f'{l1}'
    if result:
        print(f'{l} tno: {test_no} {msg} PASSED ')
    else:
        print(f'{l}: tno: {test_no} {msg} FAILED ')
        sys.exit(1)

# template crmstat to copy and change values.
#mys=crm_stat(stotal=1,sidle=1,sactive=0,sfail=0,vtotal=1,vprovision=1,vactive=0,'vidle', vdeleted=0)
#print(mys)


def check_stat(s1):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_stat()
    mycheck((s==s1),f'{s1} == {s}', lno)

def check_server_count(count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_servers(state)
    mycheck(len(s) == count, f'server_count {len(s)} == {count} for state {state}', lno)

    s=crm.get_servers('any')
    c=0
    for i in s:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c == count, f'server_count {c} == {count} for state {state}', lno)

def check_server_state(sname, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    assert(state != 'any')
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sname and i.state == state:
            f=1
            break
    mycheck(f==1, f'server {sname} with state {state} found', lno)
    s=crm.get_servers(state)
    f=0
    for i in s:
        if i.sc.name == sname and i.state == state:
            f=1
            break
    mycheck(f==1, f'server {sname} with state {state} found', lno)

def check_vm_count(count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_vms(state)
    mycheck(len(s) == count, f'vm count {len(s)} == {count} for state {state}', lno)

    s=crm.get_vms('any')
    c=0
    for i in s:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms(state)
        for j in v:
            c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms('any')
        for j in v:
            if state != 'any' and j.state != state:
                continue
            c += 1
    mycheck(c == count, f'vm count {c} == {count} for state {state}', lno)



def check_server_vm_count(sr, count, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=fs.get_vms('any')
    c=0
    for i in v:
        if state != 'any' and i.state != state:
            continue
        c += 1
    mycheck(c==count, f'vm count in {sr} {c} == {count} for state={state}', lno) 
    if state == 'any':
        return
    v=fs.get_vms(state)
    c=0
    for i in v:
        c += 1
    mycheck(c==count, f'vm count in {sr} {c} == {count} for state={state}', lno) 

def check_server_vm_state(sr, vm, state):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=crm.get_vms('any')
    f=0
    for i in v:
        if i.vc.name == vm:
            f=1
            fv=i
            break
    if f != 1:
        mycheck(0, f'vm {vm} in {sr} lookup', lno)
    mycheck(fv.state==state, f'vm: {fv.vc.name} state {fv.state} == {state}', lno) 

def check_novm(vm):
    cf=currentframe()
    lno=cf.f_back.f_lineno

    s=crm.get_vms('any')
    c=0
    for i in s:
        if i.vc.name == vm:
            c += 1
    mycheck(c == 0, f'vm {vm} not present', lno)
    c=0
    s=crm.get_servers('any')
    for i in s:
        v=i.get_vms('any')
        for j in v:
            if j.vc.name == vm:
                c += 1
    mycheck(c == 0, f'vm {vm} not present', lno)

def check_server_novm(sr, vm):
    cf=currentframe()
    lno=cf.f_back.f_lineno
    s=crm.get_servers('any')
    f=0
    for i in s:
        if i.sc.name == sr:
            f=1
            fs=i
            break
    if f != 1:
        mycheck(0, f'server {sr} lookup', lno)

    v=crm.get_vms('any')
    f=0
    for i in v:
        if i.vc.name == vm:
            f=1
            fv=i
            break
    mycheck(f==0, f'vm: {vm}  in server {sr} not present', lno) 

aggr=namedtuple('aggr', 'ncpu mem')
vmt=namedtuple('vmt', 'ncpu mem')
testvm=namedtuple('testvm', 'vc pvm')

def get_available():
    available_cpus=0
    available_mem=0
    avails=[]
    s=crm.get_servers('any')
    for i in s:
        available_cpus += i.acpu
        available_mem += i.amem
        avails.append(sconf(i.sc.name, i.acpu, i.amem))

    print(avails)
    y=aggr(available_cpus, available_mem)
    return y
         
    
global crm
crm=mycrm()
a = crm.add("s1", 500, 1000)
print(a.sc)
check_server_count(1, 'any')
s=crm.get_servers('any')
mycheck((len(s) == 1), "get servers should return one entry")
check_server_count(1, 'idle')
check_server_state('s1', 'idle')
s=crm.get_stat()
check_stat(crm_stat(stotal=1,sidle=1))
crm.fail(a.sc.name)
check_stat(crm_stat(stotal=1,sfail=1))
check_server_state('s1', 'fail')
crm.unfail(a.sc.name)
check_stat(crm_stat(stotal=1,sidle=1))
check_server_state('s1', 'idle')
crm.delete_server(a.sc.name)
check_stat(crm_stat(sdeleted=1))
check_server_count(0, 'any')

print(f'*********crm_1server tests done *********')
print(f'*********crm_1server tests done *********')
