# %%
import numpy as np
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
from geopy.geocoders import Nominatim 
import requests 
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans
import folium

# %%
file=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %% [markdown]
# ## Creating a DataFrame from the Wikipedia data

# %%
neighbourhood_df=pd.DataFrame(file[0])
neighbourhood_df.columns=['PostCode','Borough','Neighbourhood']
neighbourhood_df.drop(0,inplace=True)
neighbourhood_df.head()
# Out:
#   PostCode           Borough     Neighbourhood
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights

# %%
neighbourhood_df.shape[0]
# Out:
# 286

# %%
pCode=neighbourhood['PostCode'].unique()

# %%
neighbourhood_df
# Out:
# Empty DataFrame
# Columns: [PostCode, Borough, Neighbourhood]
# Index: []

# %%
neighbourhood_df
# Out:
# Empty DataFrame
# Columns: [PostCode, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# # Changing the data into required format.

# %%
pCode=neighbourhood_df.PostCode.unique()

# %%
neighbourhood=pd.DataFrame(columns=neighbourhood_df.columns)
for i in zip(pCode):
    count=neighbourhood_df[neighbourhood_df['PostCode']==str(i[0])].count()[1]
    df=pd.DataFrame(neighbourhood_df[neighbourhood_df['PostCode']==i[0]])
    borough=df['Borough'].unique()[0]
    for j in range(count+1):
        df=pd.DataFrame(neighbourhood_df[neighbourhood_df['PostCode']==i[0]])
        n_append=''
        l=df['Neighbourhood'].values
        for k in range(len(l)):
            n_append=n_append+str(l[k])+','
        n_append=n_append[0:len(n_append)-1]
    temp=pd.DataFrame([[i[0],borough,n_append]],columns=neighbourhood_df.columns)
    neighbourhood=neighbourhood.append(temp)

# %%
neighbourhood.reset_index(inplace=True)
neighbourhood.drop('index',axis=1,inplace=True)

# %%
neighbourhood
# Out:
#     PostCode           Borough  \
# 0        M2A      Not assigned
# 1        M3A        North York
# 2        M4A        North York
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M7A  Downtown Toronto
# 6        M8A      Not assigned
# 7        M9A      Queen's Park
# 8        M1B       Scarborough
# 9        M2B      Not assigned
# 10       M3B        North York
# 11       M4B         East York
# 12       M5B  Downtown Toronto
# 13       M6B        North York
# 14       M7B      Not assigned
# 15       M8B      Not assigned
# 16       M9B         Etobicoke
# 17       M1C       Scarborough
# 18       M2C      Not assigned
# 19       M3C        North York
# 20       M4C         East York
# 21       M5C  Downtown Toronto
# 22       M6C              York
# 23       M7C      Not assigned
# 24       M8C      Not assigned
# 25       M9C         Etobicoke
# 26       M1E       Scarborough
# 27       M2E      Not assigned
# 28       M3E      Not assigned
# 29       M4E      East Toronto
# 30       M5E  Downtown Toronto
# 31       M6E              York
# 32       M7E      Not assigned
# 33       M8E      Not assigned
# 34       M9E      Not assigned
# 35       M1G       Scarborough
# 36       M2G      Not assigned
# 37       M3G      Not assigned
# 38       M4G         East York
# 39       M5G  Downtown Toronto
# 40       M6G  Downtown Toronto
# 41       M7G      Not assigned
# 42       M8G      Not assigned
# 43       M9G      Not assigned
# 44       M1H       Scarborough
# 45       M2H        North York
# 46       M3H        North York
# 47       M4H         East York
# 48       M5H  Downtown Toronto
# 49       M6H      West Toronto
# 50       M7H      Not assigned
# 51       M8H      Not assigned
# 52       M9H      Not assigned
# 53       M1J       Scarborough
# 54       M2J        North York
# 55       M3J        North York
# 56       M4J         East York
# 57       M5J  Downtown Toronto
# 58       M6J      West Toronto
# 59       M7J      Not assigned
# 60       M8J      Not assigned
# 61       M9J      Not assigned
# 62       M1K       Scarborough
# 63       M2K        North York
# 64       M3K        North York
# 65       M4K      East Toronto
# 66       M5K  Downtown Toronto
# 67       M6K      West Toronto
# 68       M7K      Not assigned
# 69       M8K      Not assigned
# 70       M9K      Not assigned
# 71       M1L       Scarborough
# 72       M2L        North York
# 73       M3L        North York
# 74       M4L      East Toronto
# 75       M5L  Downtown Toronto
# 76       M6L        North York
# 77       M7L      Not assigned
# 78       M8L      Not assigned
# 79       M9L        North York
# 80       M1M       Scarborough
# 81       M2M        North York
# 82       M3M        North York
# 83       M4M      East Toronto
# 84       M5M        North York
# 85       M6M              York
# 86       M7M      Not assigned
# 87       M8M      Not assigned
# 88       M9M        North York
# 89       M1N       Scarborough
# 90       M2N        North York
# 91       M3N        North York
# 92       M4N   Central Toronto
# 93       M5N   Central Toronto
# 94       M6N              York
# 95       M7N      Not assigned
# 96       M8N      Not assigned
# 97       M9N              York
# 98       M1P       Scarborough
# 99       M2P        North York
# 100      M3P      Not assigned
# 101      M4P   Central Toronto
# 102      M5P   Central Toronto
# 103      M6P      West Toronto
# 104      M7P      Not assigned
# 105      M8P      Not assigned
# 106      M9P         Etobicoke
# 107      M1R       Scarborough
# 108      M2R        North York
# 109      M3R      Not assigned
# 110      M4R   Central Toronto
# 111      M5R   Central Toronto
# 112      M6R      West Toronto
# 113      M7R       Mississauga
# 114      M8R      Not assigned
# 115      M9R         Etobicoke
# 116      M1S       Scarborough
# 117      M2S      Not assigned
# 118      M3S      Not assigned
# 119      M4S   Central Toronto
# 120      M5S  Downtown Toronto
# 121      M6S      West Toronto
# 122      M7S      Not assigned
# 123      M8S      Not assigned
# 124      M9S      Not assigned
# 125      M1T       Scarborough
# 126      M2T      Not assigned
# 127      M3T      Not assigned
# 128      M4T   Central Toronto
# 129      M5T  Downtown Toronto
# 130      M6T      Not assigned
# 131      M7T      Not assigned
# 132      M8T      Not assigned
# 133      M9T      Not assigned
# 134      M1V       Scarborough
# 135      M2V      Not assigned
# 136      M3V      Not assigned
# 137      M4V   Central Toronto
# 138      M5V  Downtown Toronto
# 139      M6V      Not assigned
# 140      M7V      Not assigned
# 141      M8V         Etobicoke
# 142      M9V         Etobicoke
# 143      M1W       Scarborough
# 144      M2W      Not assigned
# 145      M3W      Not assigned
# 146      M4W  Downtown Toronto
# 147      M5W  Downtown Toronto
# 148      M6W      Not assigned
# 149      M7W      Not assigned
# 150      M8W         Etobicoke
# 151      M9W         Etobicoke
# 152      M1X       Scarborough
# 153      M2X      Not assigned
# 154      M3X      Not assigned
# 155      M4X  Downtown Toronto
# 156      M5X  Downtown Toronto
# 157      M6X      Not assigned
# 158      M7X      Not assigned
# 159      M8X         Etobicoke
# 160      M9X      Not assigned
# 161      M1Y      Not assigned
# 162      M2Y      Not assigned
# 163      M3Y      Not assigned
# 164      M4Y  Downtown Toronto
# 165      M5Y      Not assigned
# 166      M6Y      Not assigned
# 167      M7Y      East Toronto
# 168      M8Y         Etobicoke
# 169      M9Y      Not assigned
# 170      M1Z      Not assigned
# 171      M2Z      Not assigned
# 172      M3Z      Not assigned
# 173      M4Z      Not assigned
# 174      M5Z      Not assigned
# 175      M6Z      Not assigned
# 176      M7Z      Not assigned
# 177      M8Z         Etobicoke
# 178      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                            Parkwoods
# 2                                     Victoria Village
# 3                                         Harbourfront
# 4                      Lawrence Heights,Lawrence Manor
# 5                                         Queen's Park
# 6                                         Not assigned
# 7                                         Not assigned
# 8                                        Rouge,Malvern
# 9                                         Not assigned
# 10                                     Don Mills North
# 11                      Woodbine Gardens,Parkview Hill
# 12                             Ryerson,Garden District
# 13                                           Glencairn
# 14                                        Not assigned
# 15                                        Not assigned
# 16   Cloverdale,Islington,Martin Grove,Princess Gar...
# 17                Highland Creek,Rouge Hill,Port Union
# 18                                        Not assigned
# 19                     Flemingdon Park,Don Mills South
# 20                                    Woodbine Heights
# 21                                      St. James Town
# 22                                  Humewood-Cedarvale
# 23                                        Not assigned
# 24                                        Not assigned
# 25   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 26                     Guildwood,Morningside,West Hill
# 27                                        Not assigned
# 28                                        Not assigned
# 29                                         The Beaches
# 30                                         Berczy Park
# 31                                 Caledonia-Fairbanks
# 32                                        Not assigned
# 33                                        Not assigned
# 34                                        Not assigned
# 35                                              Woburn
# 36                                        Not assigned
# 37                                        Not assigned
# 38                                             Leaside
# 39                                  Central Bay Street
# 40                                            Christie
# 41                                        Not assigned
# 42                                        Not assigned
# 43                                        Not assigned
# 44                                           Cedarbrae
# 45                                   Hillcrest Village
# 46       Bathurst Manor,Downsview North,Wilson Heights
# 47                                    Thorncliffe Park
# 48                              Adelaide,King,Richmond
# 49                         Dovercourt Village,Dufferin
# 50                                        Not assigned
# 51                                        Not assigned
# 52                                        Not assigned
# 53                                 Scarborough Village
# 54                          Fairview,Henry Farm,Oriole
# 55                      Northwood Park,York University
# 56                                        East Toronto
# 57     Harbourfront East,Toronto Islands,Union Station
# 58                             Little Portugal,Trinity
# 59                                        Not assigned
# 60                                        Not assigned
# 61                                        Not assigned
# 62           East Birchmount Park,Ionview,Kennedy Park
# 63                                     Bayview Village
# 64                          CFB Toronto,Downsview East
# 65                         The Danforth West,Riverdale
# 66             Design Exchange,Toronto Dominion Centre
# 67          Brockton,Exhibition Place,Parkdale Village
# 68                                        Not assigned
# 69                                        Not assigned
# 70                                        Not assigned
# 71                       Clairlea,Golden Mile,Oakridge
# 72                             Silver Hills,York Mills
# 73                                      Downsview West
# 74                       The Beaches West,India Bazaar
# 75                       Commerce Court,Victoria Hotel
# 76                    Downsview,North Park,Upwood Park
# 77                                        Not assigned
# 78                                        Not assigned
# 79                                       Humber Summit
# 80       Cliffcrest,Cliffside,Scarborough Village West
# 81                              Newtonbrook,Willowdale
# 82                                   Downsview Central
# 83                                     Studio District
# 84                    Bedford Park,Lawrence Manor East
# 85         Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 86                                        Not assigned
# 87                                        Not assigned
# 88                                     Emery,Humberlea
# 89                          Birch Cliff,Cliffside West
# 90                                    Willowdale South
# 91                                 Downsview Northwest
# 92                                       Lawrence Park
# 93                                            Roselawn
# 94                        The Junction North,Runnymede
# 95                                        Not assigned
# 96                                        Not assigned
# 97                                              Weston
# 98   Dorset Park,Scarborough Town Centre,Wexford He...
# 99                                     York Mills West
# 100                                       Not assigned
# 101                                   Davisville North
# 102                 Forest Hill North,Forest Hill West
# 103                       High Park,The Junction South
# 104                                       Not assigned
# 105                                       Not assigned
# 106                                          Westmount
# 107                                   Maryvale,Wexford
# 108                                    Willowdale West
# 109                                       Not assigned
# 110                                 North Toronto West
# 111                  The Annex,North Midtown,Yorkville
# 112                              Parkdale,Roncesvalles
# 113              Canada Post Gateway Processing Centre
# 114                                       Not assigned
# 115  Kingsview Village,Martin Grove Gardens,Richvie...
# 116                                          Agincourt
# 117                                       Not assigned
# 118                                       Not assigned
# 119                                         Davisville
# 120                      Harbord,University of Toronto
# 121                                  Runnymede,Swansea
# 122                                       Not assigned
# 123                                       Not assigned
# 124                                       Not assigned
# 125              Clarks Corners,Sullivan,Tam O'Shanter
# 126                                       Not assigned
# 127                                       Not assigned
# 128                         Moore Park,Summerhill East
# 129            Chinatown,Grange Park,Kensington Market
# 130                                       Not assigned
# 131                                       Not assigned
# 132                                       Not assigned
# 133                                       Not assigned
# 134  Agincourt North,L'Amoreaux East,Milliken,Steel...
# 135                                       Not assigned
# 136                                       Not assigned
# 137  Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 138  CN Tower,Bathurst Quay,Island airport,Harbourf...
# 139                                       Not assigned
# 140                                       Not assigned
# 141         Humber Bay Shores,Mimico South,New Toronto
# 142  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 143                                    L'Amoreaux West
# 144                                       Not assigned
# 145                                       Not assigned
# 146                                           Rosedale
# 147                    Stn A PO Boxes 25 The Esplanade
# 148                                       Not assigned
# 149                                       Not assigned
# 150                              Alderwood,Long Branch
# 151                                          Northwest
# 152                                        Upper Rouge
# 153                                       Not assigned
# 154                                       Not assigned
# 155                         Cabbagetown,St. James Town
# 156              First Canadian Place,Underground city
# 157                                       Not assigned
# 158                                       Not assigned
# 159        The Kingsway,Montgomery Road,Old Mill North
# 160                                       Not assigned
# 161                                       Not assigned
# 162                                       Not assigned
# 163                                       Not assigned
# 164                               Church and Wellesley
# 165                                       Not assigned
# 166                                       Not assigned
# 167  Business Reply Mail Processing Centre 969 Eastern
# 168  Humber Bay,King's Mill Park,Kingsway Park Sout...
# 169                                       Not assigned
# 170                                       Not assigned
# 171                                       Not assigned
# 172                                       Not assigned
# 173                                       Not assigned
# 174                                       Not assigned
# 175                                       Not assigned
# 176                                       Not assigned
# 177  Kingsway Park South West,Mimico NW,The Queensw...
# 178                                       Not assigned

# %%
# Removing the rows where values are not assigned
neighbourhood.drop(neighbourhood[neighbourhood['Neighbourhood']=='Not assigned'].index,inplace=True)
neighbourhood.drop(neighbourhood[neighbourhood['Borough']=='Not assigned'].index,inplace=True)

# %%
geolocator=Nominatim(user_agent='foursquare_agent')

# %%
df=pd.DataFrame(neighbourhood[neighbourhood['PostCode']=='M6A'])
n_append=''
l=df['Neighbourhood'].values
for i in range(len(l)):
    n_append=n_append+str(l[i])+','
n_append=n_append[0:len(n_append)-1]
n_append
# Out:
# 'Lawrence Heights,Lawrence Manor'

# %%
lat=[]
long=[]
index=[]
for i,val in neighbourhood.iterrows():
    location=str(val['Neighbourhood'])+', Toronto'
    
    try:
        address=geolocator.geocode(location)
        lat.append(address.latitude)
        long.append(address.longitude)
    except:
        try:
            address=geolocator.geocode(location)
            lat.append(address.latitude)
            long.append(address.longitude)
        except:
            index.append(i)

# %%
neighbourhood.drop(index,inplace=True)

# %%
neighbourhood['Latitude']=lat
neighbourhood['Longitude']=long

# %%
neighbourhood
# Out:
#     PostCode           Borough                            Neighbourhood  \
# 1        M3A        North York                                Parkwoods
# 2        M4A        North York                         Victoria Village
# 3        M5A  Downtown Toronto                             Harbourfront
# 4        M6A        North York          Lawrence Heights,Lawrence Manor
# 5        M7A  Downtown Toronto                             Queen's Park
# 8        M1B       Scarborough                            Rouge,Malvern
# 10       M3B        North York                          Don Mills North
# 11       M4B         East York           Woodbine Gardens,Parkview Hill
# 12       M5B  Downtown Toronto                  Ryerson,Garden District
# 13       M6B        North York                                Glencairn
# 19       M3C        North York          Flemingdon Park,Don Mills South
# 20       M4C         East York                         Woodbine Heights
# 21       M5C  Downtown Toronto                           St. James Town
# 26       M1E       Scarborough          Guildwood,Morningside,West Hill
# 29       M4E      East Toronto                              The Beaches
# 30       M5E  Downtown Toronto                              Berczy Park
# 35       M1G       Scarborough                                   Woburn
# 38       M4G         East York                                  Leaside
# 39       M5G  Downtown Toronto                       Central Bay Street
# 40       M6G  Downtown Toronto                                 Christie
# 44       M1H       Scarborough                                Cedarbrae
# 45       M2H        North York                        Hillcrest Village
# 47       M4H         East York                         Thorncliffe Park
# 49       M6H      West Toronto              Dovercourt Village,Dufferin
# 53       M1J       Scarborough                      Scarborough Village
# 56       M4J         East York                             East Toronto
# 63       M2K        North York                          Bayview Village
# 65       M4K      East Toronto              The Danforth West,Riverdale
# 66       M5K  Downtown Toronto  Design Exchange,Toronto Dominion Centre
# 72       M2L        North York                  Silver Hills,York Mills
# 73       M3L        North York                           Downsview West
# 75       M5L  Downtown Toronto            Commerce Court,Victoria Hotel
# 79       M9L        North York                            Humber Summit
# 81       M2M        North York                   Newtonbrook,Willowdale
# 82       M3M        North York                        Downsview Central
# 83       M4M      East Toronto                          Studio District
# 88       M9M        North York                          Emery,Humberlea
# 90       M2N        North York                         Willowdale South
# 91       M3N        North York                      Downsview Northwest
# 92       M4N   Central Toronto                            Lawrence Park
# 93       M5N   Central Toronto                                 Roselawn
# 94       M6N              York             The Junction North,Runnymede
# 97       M9N              York                                   Weston
# 99       M2P        North York                          York Mills West
# 101      M4P   Central Toronto                         Davisville North
# 106      M9P         Etobicoke                                Westmount
# 107      M1R       Scarborough                         Maryvale,Wexford
# 108      M2R        North York                          Willowdale West
# 110      M4R   Central Toronto                       North Toronto West
# 112      M6R      West Toronto                    Parkdale,Roncesvalles
# 116      M1S       Scarborough                                Agincourt
# 119      M4S   Central Toronto                               Davisville
# 121      M6S      West Toronto                        Runnymede,Swansea
# 143      M1W       Scarborough                          L'Amoreaux West
# 146      M4W  Downtown Toronto                                 Rosedale
# 150      M8W         Etobicoke                    Alderwood,Long Branch
# 151      M9W         Etobicoke                                Northwest
# 152      M1X       Scarborough                              Upper Rouge
# 164      M4Y  Downtown Toronto                     Church and Wellesley
#
#       Latitude  Longitude
# 1    43.758800 -79.320197
# 2    43.732658 -79.311189
# 3    43.640080 -79.380150
# 4    43.722778 -79.450933
# 5    43.659659 -79.390340
# 8    43.779300 -79.257126
# 10   43.775347 -79.345944
# 11   43.714531 -79.309490
# 12   43.660106 -79.376588
# 13   43.708712 -79.440685
# 19   43.721159 -79.349111
# 20   43.699930 -79.319132
# 21   43.669403 -79.372704
# 26   43.753480 -79.179995
# 29   43.671024 -79.296712
# 30   43.647984 -79.375396
# 35   43.759824 -79.225291
# 38   43.704798 -79.368090
# 39   43.656119 -79.384670
# 40   43.664111 -79.418405
# 44   43.756467 -79.226692
# 45   43.799664 -79.365019
# 47   43.704553 -79.345407
# 49   43.656239 -79.427410
# 53   43.743742 -79.211632
# 56   43.653963 -79.387207
# 63   43.769197 -79.376662
# 65   43.660400 -79.343764
# 66   43.647741 -79.380115
# 72   43.748964 -79.353729
# 73   43.749299 -79.462248
# 75   43.648164 -79.377766
# 79   43.760078 -79.571760
# 81   43.793886 -79.425679
# 82   43.749299 -79.462248
# 83   43.644403 -79.387891
# 88   43.719268 -79.537142
# 90   43.761510 -79.410923
# 91   43.749299 -79.462248
# 92   43.729199 -79.403252
# 93   43.699456 -79.454616
# 94   43.665116 -79.465570
# 97   43.700161 -79.516247
# 99   43.744039 -79.406657
# 101  43.697936 -79.397291
# 106  43.693640 -79.521043
# 107  43.761244 -79.296855
# 108  43.761510 -79.410923
# 110  43.653963 -79.387207
# 112  43.641281 -79.451599
# 116  43.785353 -79.278549
# 119  43.697936 -79.397291
# 121  43.651778 -79.475923
# 143  43.799003 -79.305967
# 146  43.678356 -79.380746
# 150  43.601717 -79.545232
# 151  43.653963 -79.387207
# 152  43.804930 -79.165837
# 164  43.665524 -79.383801

# %% [markdown]
# ## Visualizing the neighborhoods on Map

# %%
latT=43.6532
lonT=-79.382
map=folium.Map(location=[latT,lonT],zoom_start=12)

folium.CircleMarker(
                        [latT,lonT],
                        label='Toronto',
                        radius=5,
                        color='blue',fill=True,fillcolor='blue',fillopacity=0.3).add_to(map)
for lat,long,lab in zip(neighbourhood['Latitude'],neighbourhood['Longitude'],neighbourhood['Neighbourhood']):
    folium.CircleMarker(
                        [lat,long],
                        label=lab,
                        radius=5,
                        color='red',fill=True,fillcolor='red',fillopacity=0.3).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
neighbourhood.shape
# Out:
# (59, 5)
