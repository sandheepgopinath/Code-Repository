# %%
import cv2


cap=cv2.VideoCapture(0)

while True:
    ret,frame=cap.read()
    
    cv2.imshow('Stream',frame)
    if cv2.waitKey(1) & 0xff==ord('q'):
        break
cv2.DestroyAllWindows()
cap.release()
# Out:
# QObject::moveToThread: Current thread (0x5605ea482920) is not the object's thread (0x5605ec41d0b0).
# Cannot move to target thread (0x5605ea482920)
#
# QObject::moveToThread: Current thread (0x5605ea482920) is not the object's thread (0x5605ec41d0b0).
# Cannot move to target thread (0x5605ea482920)
#
# QObject::moveToThread: Current thread (0x5605ea482920) is not the object's thread (0x5605ec41d0b0).
# Cannot move to target thread (0x5605ea482920)
#
# QObject::moveToThread: Current thread (0x5605ea482920) is not the object's thread (0x5605ec41d0b0).
# Cannot move to target thread (0x5605ea482920)
#
# QObject::moveToThread: Current thread (0x5605ea482920) is not the object's thread (0x5605ec41d0b0).
# Cannot move to target thread (0x5605ea482920)
#
# QObject::moveToThread: Current thread (0x5605ea482920) is not the object's thread (0x5605ec41d0b0).
# Cannot move to target thread (0x5605ea482920)
#
# ...
