# %% [markdown]
# # Exploratory Data Analysis

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import numpy as np

# %%
np.random.seed(1)

# %%
# Reading the data
train=pd.read_csv('cs-training.csv')
test=pd.read_csv('cs-test.csv')

# Combine train and test in a list for easy processing
combine=[train,test]

for data in combine:
    # Dropping the index column
    data.drop(data.columns[0],axis=1,inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        150000 non-null int64
# RevolvingUtilizationOfUnsecuredLines    150000 non-null float64
# age                                     150000 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    150000 non-null int64
# DebtRatio                               150000 non-null float64
# MonthlyIncome                           120269 non-null float64
# NumberOfOpenCreditLinesAndLoans         150000 non-null int64
# NumberOfTimes90DaysLate                 150000 non-null int64
# NumberRealEstateLoansOrLines            150000 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    150000 non-null int64
# NumberOfDependents                      146076 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 12.6 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101503 entries, 0 to 101502
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        0 non-null float64
# RevolvingUtilizationOfUnsecuredLines    101503 non-null float64
# age                                     101503 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    101503 non-null int64
# DebtRatio                               101503 non-null float64
# MonthlyIncome                           81400 non-null float64
# NumberOfOpenCreditLinesAndLoans         101503 non-null int64
# NumberOfTimes90DaysLate                 101503 non-null int64
# NumberRealEstateLoansOrLines            101503 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    101503 non-null int64
# NumberOfDependents                      98877 non-null float64
# dtypes: float64(5), int64(6)
# memory usage: 8.5 MB

# %% [markdown]
# # Dataset Analysis

# %%
data_sizes=[train.shape[0],test.shape[0]]
labels=['Train dataset','Test Dataset']
plt.figure(figsize=(5,5))
plt.pie(data_sizes,labels=labels,autopct='%.0f%%',explode=[0.05,0.0])
plt.show()

# %%
train['SeriousDlqin2yrs'].value_counts()
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %%
# Checking the data distribution
plt.figure(figsize=(5,5))
plt.pie(train['SeriousDlqin2yrs'].value_counts().values,labels=['Class 0','Class 1'],explode=[0.05,0.0],autopct='%.0f%%')
plt.show()

# %%
# Missing values
i=1
combine_info=[]
for data in combine:
    numbers=[]
    for column in data.columns:
        numbers.append(data[column].notna().sum())
    combine_info.append(numbers)

# %%
import pandas as pd
df=pd.DataFrame()
df['Attribute']=combine[0].columns
df['Count']=combine_info[0]
df
# Out:
#                                Attribute   Count
# 0                       SeriousDlqin2yrs  150000
# 1   RevolvingUtilizationOfUnsecuredLines  150000
# 2                                    age  150000
# 3   NumberOfTime30-59DaysPastDueNotWorse  150000
# 4                              DebtRatio  150000
# 5                          MonthlyIncome  120269
# 6        NumberOfOpenCreditLinesAndLoans  150000
# 7                NumberOfTimes90DaysLate  150000
# 8           NumberRealEstateLoansOrLines  150000
# 9   NumberOfTime60-89DaysPastDueNotWorse  150000
# 10                    NumberOfDependents  146076

# %%
plt.figure(figsize=(50,10))
plots = sns.barplot(x=df['Attribute'], y=df['Count'], data=df)
                                           
# Iterrating over the bars one-by-one
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
  plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %%
import pandas as pd
df=pd.DataFrame()
df['Attribute']=combine[1].columns
df['Count']=combine_info[1]
df
# Out:
#                                Attribute   Count
# 0                       SeriousDlqin2yrs       0
# 1   RevolvingUtilizationOfUnsecuredLines  101503
# 2                                    age  101503
# 3   NumberOfTime30-59DaysPastDueNotWorse  101503
# 4                              DebtRatio  101503
# 5                          MonthlyIncome   81400
# 6        NumberOfOpenCreditLinesAndLoans  101503
# 7                NumberOfTimes90DaysLate  101503
# 8           NumberRealEstateLoansOrLines  101503
# 9   NumberOfTime60-89DaysPastDueNotWorse  101503
# 10                    NumberOfDependents   98877

# %%
plt.figure(figsize=(50,10))
plots = sns.barplot(x=df['Attribute'], y=df['Count'], data=df)
                                           
# Iterrating over the bars one-by-one
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
  plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %% [markdown]
# # Dropping the row with 0 age

# %%
train.drop(train[train['age']==0].index,axis=0,inplace=True)

# %% [markdown]
# # Filling the missing values

# %% [markdown]
# # Using a Random Forest Regressor to predict the Number of Dependents

# %%
import warnings
warnings.filterwarnings("ignore")
dependent_predictors=['age','NumberOfOpenCreditLinesAndLoans','NumberRealEstateLoansOrLines']
x=train[train['NumberOfDependents'].notna()]
y=x['NumberOfDependents']
x=x[dependent_predictors]

from sklearn.ensemble import RandomForestClassifier
lr=RandomForestClassifier(random_state=1)
lr.fit(x,y)
lr.score(x,y)
# Out:
# 0.6084066404244395

# %%
from tqdm import tqdm
for data in tqdm(combine):
    nod=[]
    for i,row in data.iterrows():
        if np.isnan(row['NumberOfDependents']):
            nod.append(lr.predict(np.array([row['age'],row['NumberOfOpenCreditLinesAndLoans'],row['NumberRealEstateLoansOrLines']]).reshape(1,-1)))
        else:
            nod.append(row['NumberOfDependents'])
    data['NumberOfDependents']=nod
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:10<00:10, 10.59s/it]
#
# 100%|██████████| 2/2 [00:17<00:00,  9.62s/it]

# %%
test[test['NumberOfDependents'].isna()]
# Out:
# Empty DataFrame
# Columns: [SeriousDlqin2yrs, RevolvingUtilizationOfUnsecuredLines, age, NumberOfTime30-59DaysPastDueNotWorse, DebtRatio, MonthlyIncome, NumberOfOpenCreditLinesAndLoans, NumberOfTimes90DaysLate, NumberRealEstateLoansOrLines, NumberOfTime60-89DaysPastDueNotWorse, NumberOfDependents]
# Index: []

# %% [markdown]
# # Predicting the Monthly Income

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=1)
dependent_predictors=['RevolvingUtilizationOfUnsecuredLines', 'age',
       'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio',
       'NumberOfOpenCreditLinesAndLoans',
       'NumberRealEstateLoansOrLines',
       'NumberOfDependents']
x=train[train['MonthlyIncome'].notna()]
y=x['MonthlyIncome']
x=x[dependent_predictors]

# %%
rfr.fit(x,y)
rfr.score(x,y)
# Out:
# 0.7723692850950064

# %%
attributes=['RevolvingUtilizationOfUnsecuredLines', 'age',
       'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio',
       'NumberOfOpenCreditLinesAndLoans',
       'NumberRealEstateLoansOrLines',
       'NumberOfDependents','MonthlyIncome']

# %%
for data in tqdm(combine):
    mi=[]
    mi_predict=data[attributes]
    for i,row in mi_predict.iterrows():
        if np.isnan(row['MonthlyIncome']):
            mi.append(rfr.predict(np.array(row[:-1]).reshape(1,-1)))
        else:
            mi.append(row['MonthlyIncome'])
    data['MonthlyIncome']=mi
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:32<00:32, 32.85s/it]
#
# 100%|██████████| 2/2 [00:54<00:00, 29.52s/it]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101503 entries, 0 to 101502
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        0 non-null float64
# RevolvingUtilizationOfUnsecuredLines    101503 non-null float64
# age                                     101503 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    101503 non-null int64
# DebtRatio                               101503 non-null float64
# MonthlyIncome                           101503 non-null object
# NumberOfOpenCreditLinesAndLoans         101503 non-null int64
# NumberOfTimes90DaysLate                 101503 non-null int64
# NumberRealEstateLoansOrLines            101503 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    101503 non-null int64
# NumberOfDependents                      101503 non-null object
# dtypes: float64(3), int64(6), object(2)
# memory usage: 8.5+ MB

# %%
# Converting monthly income to float
for data in combine:
    data['MonthlyIncome']=data['MonthlyIncome'].astype('float')
    data['NumberOfDependents']=data['NumberOfDependents'].astype('float')

# %% [markdown]
# # Checking the Correaltion between variables

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(),annot=True)
plt.xticks(rotation=80)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <a list of 11 Text xticklabel objects>)

# %%
train.columns
# Out:
# Index(['SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %%
# Combining the columns with high correalation
for data in combine:
        data['due']=data['NumberOfTime30-59DaysPastDueNotWorse']+(2*data['NumberOfTime60-89DaysPastDueNotWorse'])+(3*data['NumberOfTimes90DaysLate'])
    
columns_to_be_dropped=['NumberOfTime30-59DaysPastDueNotWorse','NumberOfTime60-89DaysPastDueNotWorse','NumberOfTimes90DaysLate']
for data in combine:
    data.drop(columns_to_be_dropped,axis=1,inplace=True)

# %%
train.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  DebtRatio  \
# 0                 1                              0.766127   45   0.802982
# 1                 0                              0.957151   40   0.121876
# 2                 0                              0.658180   38   0.085113
# 3                 0                              0.233810   30   0.036050
# 4                 0                              0.907239   49   0.024926
#
#    MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# 0         9120.0                               13
# 1         2600.0                                4
# 2         3042.0                                2
# 3         3300.0                                5
# 4        63588.0                                7
#
#    NumberRealEstateLoansOrLines  NumberOfDependents  due
# 0                             6                 2.0    2
# 1                             0                 1.0    0
# 2                             0                 0.0    4
# 3                             0                 0.0    0
# 4                             1                 0.0    1

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(),annot=True)
plt.xticks(rotation=80)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  <a list of 9 Text xticklabel objects>)

# %% [markdown]
# # Univariate data analysis

# %%
train.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     149999.000000                         149999.000000  149999.000000
# mean           0.066840                              6.048472      52.295555
# std            0.249746                            249.756203      14.771298
# min            0.000000                              0.000000      21.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154176      52.000000
# 75%            0.000000                              0.559044      63.000000
# max            1.000000                          50708.000000     109.000000
#
#            DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# count  149999.000000   1.499990e+05                    149999.000000
# mean      353.007426   5.412641e+03                         8.452776
# std      2037.825113   1.322119e+04                         5.145964
# min         0.000000   0.000000e+00                         0.000000
# 25%         0.175074   1.798000e+03                         5.000000
# 50%         0.366503   4.400000e+03                         8.000000
# 75%         0.868257   7.400000e+03                        11.000000
# max    329664.000000   3.008750e+06                        58.000000
#
#        NumberRealEstateLoansOrLines  NumberOfDependents            due
# count                 149999.000000       149999.000000  149999.000000
# mean                       1.018233            0.738232       1.699731
# std                        1.129772            1.107168      24.928575
# min                        0.000000            0.000000       0.000000
# 25%                        0.000000            0.000000       0.000000
# 50%                        1.000000            0.000000       0.000000
# 75%                        2.000000            1.000000       0.000000
# max                       54.000000           20.000000     588.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149999 entries, 0 to 149999
# Data columns (total 9 columns):
# SeriousDlqin2yrs                        149999 non-null int64
# RevolvingUtilizationOfUnsecuredLines    149999 non-null float64
# age                                     149999 non-null int64
# DebtRatio                               149999 non-null float64
# MonthlyIncome                           149999 non-null float64
# NumberOfOpenCreditLinesAndLoans         149999 non-null int64
# NumberRealEstateLoansOrLines            149999 non-null int64
# NumberOfDependents                      149999 non-null float64
# due                                     149999 non-null int64
# dtypes: float64(4), int64(5)
# memory usage: 11.4 MB

# %%
plt.figure(figsize=(10,30))
i=1
for column in train.columns[1:]:
    plt.subplot(8,1,i)
    sns.boxplot(train[column])
    i+=1

# %% [markdown]
# # Normalising the data before feeding into the deep learning network

# %%
columns=combine[0].columns

# %%
x_train=combine[0].drop(['SeriousDlqin2yrs'],axis=1)
y_train=combine[0]['SeriousDlqin2yrs']
x_test=combine[1].drop(['SeriousDlqin2yrs'],axis=1)
y_test=combine[1]['SeriousDlqin2yrs']
combine_y=[y_train,y_test]
combine_x=[x_train,x_test]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,test_size=0.25)

# %% [markdown]
# # Creating a deep learning model

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression(random_state=1)
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.9332527400243558

# %%
lr.score(x_test,y_test)
# Out:
# 0.93352

# %% [markdown]
# # AUC SCORE

# %%
from sklearn.metrics import roc_auc_score

y_pred=lr.predict_proba(x_test)
temp=[]
for value in y_pred:
    temp.append(value[1])
y_pred=temp
roc_auc_score(y_test,y_pred)
# Out:
# 0.6544900520784045

# %%
y_p=lr.predict(x_test)
count=[0,0]
for value in y_p:
    count[value]+=1
print((count[0]/len(y_p))*100,end='')
print('% of predictions belongs to one class')
# Out:
# 99.83999999999999% of predictions belongs to one class

# %%
x_train=combine[0].drop(['SeriousDlqin2yrs'],axis=1)
y_train=combine[0]['SeriousDlqin2yrs']
x_test=combine[1].drop(['SeriousDlqin2yrs'],axis=1)
y_test=combine[1]['SeriousDlqin2yrs']
combine_y=[y_train,y_test]
combine_x=[x_train,x_test]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,test_size=0.25)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
import numpy as np
x_train=np.expand_dims(x_train,axis=1)
x_test=np.expand_dims(x_test,axis=1)

# %%
import keras 
from keras import Sequential
from keras.layers import Dense

model=Sequential()

model.add(Dense(16,input_shape=(1,8),activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1, 16)             144
#
#  dense_1 (Dense)             (None, 1, 32)             544
#
#  dense_2 (Dense)             (None, 1, 16)             528
#
#  dense_3 (Dense)             (None, 1, 8)              136
#
#  dense_4 (Dense)             (None, 1, 4)              36
#
#  dense_5 (Dense)             (None, 1, 1)              5
#
# =================================================================
# Total params: 1,393
# Trainable params: 1,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test),
          batch_size=50)
# Out:
# Epoch 1/10
# 2250/2250 [==============================] - 4s 1ms/step - loss: 0.2248 - accuracy: 0.9316 - val_loss: 0.1891 - val_accuracy: 0.9348
# Epoch 2/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1937 - accuracy: 0.9326 - val_loss: 0.1895 - val_accuracy: 0.9348
# Epoch 3/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1917 - accuracy: 0.9343 - val_loss: 0.1862 - val_accuracy: 0.9378
# Epoch 4/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1909 - accuracy: 0.9353 - val_loss: 0.1869 - val_accuracy: 0.9376
# Epoch 5/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1903 - accuracy: 0.9360 - val_loss: 0.1878 - val_accuracy: 0.9376
# Epoch 6/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1897 - accuracy: 0.9363 - val_loss: 0.1849 - val_accuracy: 0.9380
# Epoch 7/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1894 - accuracy: 0.9360 - val_loss: 0.1849 - val_accuracy: 0.9375
# Epoch 8/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1892 - accuracy: 0.9362 - val_loss: 0.1855 - val_accuracy: 0.9378
# Epoch 9/10
# 2250/2250 [==============================] - 3s 2ms/step - loss: 0.1889 - accuracy: 0.9360 - val_loss: 0.1863 - val_accuracy: 0.9376
# Epoch 10/10
# 2250/2250 [==============================] - 3s 1ms/step - loss: 0.1888 - accuracy: 0.9361 - val_loss: 0.1859 - val_accuracy: 0.9378

# %%
from sklearn.metrics import roc_auc_score

y_pred=model.predict(x_test)
y_pred=np.squeeze(y_pred)
roc_auc_score(y_test,y_pred)
# Out:
# 0.8312834432832543

# %%
y_p=model.predict(x_test)
count=[0,0]
for value in y_p:
    if value>0.5:
        count[1]+=1
    else:
        count[0]+=1
print((count[0]/len(y_p))*100,end='')
print('% of predictions belongs to one class')
# Out:
# 98.19733333333333% of predictions belongs to one class

# %% [markdown]
# # Balancing the dataset

# %%
x_train=combine[0].drop(['SeriousDlqin2yrs'],axis=1)
y_train=combine[0]['SeriousDlqin2yrs']
x_test=combine[1].drop(['SeriousDlqin2yrs'],axis=1)
y_test=combine[1]['SeriousDlqin2yrs']
combine_y=[y_train,y_test]
combine_x=[x_train,x_test]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,test_size=0.25,random_state=1)

# %%
indexes=random.sample(list(y_train[y_train==0].index.values),10026)
x0=x_train.loc[indexes]
y0=y_train.loc[indexes]
indexes=list(y_train[y_train==1].index.values)
x1=x_train.loc[indexes]
y1=y_train.loc[indexes]
x_train=pd.concat([x0,x1],ignore_index=True)
y_train=pd.concat([y0,y1],ignore_index=True)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression(random_state=1)
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.7116578392846973

# %%
from sklearn.metrics import roc_auc_score

y_pred=lr.predict_proba(x_test)
temp=[]
for value in y_pred:
    temp.append(value[1])
y_pred=temp
roc_auc_score(y_test,y_pred)
# Out:
# 0.7647966939762011

# %%
y_p=lr.predict(x_test)
count=[0,0]
for value in y_p:
    count[value]+=1
print((count[0]/len(y_p))*100,end='')
print('% of predictions belongs to one class')
# Out:
# 85.05866666666667% of predictions belongs to one class

# %% [markdown]
# # Creating a deep learning model

# %%
import numpy as np
x_train=np.expand_dims(x_train,axis=1)
x_test=np.expand_dims(x_test,axis=1)

# %%
import keras 
from keras import Sequential
from keras.layers import Dense

model=Sequential()

model.add(Dense(16,input_shape=(1,8),activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=30,validation_data=(x_test,y_test),
          batch_size=50)
# Out:
# Epoch 1/30
# 352/352 [==============================] - 2s 3ms/step - loss: 0.6564 - accuracy: 0.6025 - val_loss: 0.5683 - val_accuracy: 0.7307
# Epoch 2/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.6265 - accuracy: 0.6416 - val_loss: 0.5478 - val_accuracy: 0.7485
# Epoch 3/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5928 - accuracy: 0.6863 - val_loss: 0.4461 - val_accuracy: 0.8417
# Epoch 4/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5526 - accuracy: 0.7236 - val_loss: 0.5085 - val_accuracy: 0.7856
# Epoch 5/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5321 - accuracy: 0.7414 - val_loss: 0.4466 - val_accuracy: 0.8439
# Epoch 6/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5210 - accuracy: 0.7513 - val_loss: 0.4527 - val_accuracy: 0.8459
# Epoch 7/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5148 - accuracy: 0.7532 - val_loss: 0.5209 - val_accuracy: 0.7927
# Epoch 8/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5095 - accuracy: 0.7599 - val_loss: 0.4611 - val_accuracy: 0.8245
# Epoch 9/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5062 - accuracy: 0.7617 - val_loss: 0.4584 - val_accuracy: 0.8238
# Epoch 10/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5027 - accuracy: 0.7625 - val_loss: 0.4590 - val_accuracy: 0.8445
# Epoch 11/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.5005 - accuracy: 0.7675 - val_loss: 0.4018 - val_accuracy: 0.8528
# Epoch 12/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4990 - accuracy: 0.7668 - val_loss: 0.4074 - val_accuracy: 0.8613
# Epoch 13/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4956 - accuracy: 0.7702 - val_loss: 0.5226 - val_accuracy: 0.7893
# Epoch 14/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4979 - accuracy: 0.7693 - val_loss: 0.3955 - val_accuracy: 0.8638
# Epoch 15/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4950 - accuracy: 0.7698 - val_loss: 0.3606 - val_accuracy: 0.8854
# Epoch 16/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4938 - accuracy: 0.7735 - val_loss: 0.3480 - val_accuracy: 0.8803
# Epoch 17/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4934 - accuracy: 0.7708 - val_loss: 0.3913 - val_accuracy: 0.8654
# Epoch 18/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4914 - accuracy: 0.7734 - val_loss: 0.3945 - val_accuracy: 0.8671
# Epoch 19/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4919 - accuracy: 0.7713 - val_loss: 0.3976 - val_accuracy: 0.8686
# Epoch 20/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4910 - accuracy: 0.7738 - val_loss: 0.4425 - val_accuracy: 0.8288
# Epoch 21/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4895 - accuracy: 0.7769 - val_loss: 0.4000 - val_accuracy: 0.8547
# Epoch 22/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4884 - accuracy: 0.7752 - val_loss: 0.3965 - val_accuracy: 0.8569
# Epoch 23/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4904 - accuracy: 0.7733 - val_loss: 0.3928 - val_accuracy: 0.8591
# Epoch 24/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4873 - accuracy: 0.7761 - val_loss: 0.4001 - val_accuracy: 0.8515
# Epoch 25/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4867 - accuracy: 0.7745 - val_loss: 0.5372 - val_accuracy: 0.7759
# Epoch 26/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4865 - accuracy: 0.7756 - val_loss: 0.4624 - val_accuracy: 0.8116
# Epoch 27/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4868 - accuracy: 0.7768 - val_loss: 0.4123 - val_accuracy: 0.8583
# Epoch 28/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4854 - accuracy: 0.7766 - val_loss: 0.4363 - val_accuracy: 0.8274
# Epoch 29/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4847 - accuracy: 0.7789 - val_loss: 0.3715 - val_accuracy: 0.8724
# Epoch 30/30
# 352/352 [==============================] - 1s 3ms/step - loss: 0.4841 - accuracy: 0.7783 - val_loss: 0.3696 - val_accuracy: 0.8672

# %%
from sklearn.metrics import roc_auc_score

y_pred=model.predict(x_test)
y_pred=np.squeeze(y_pred)
roc_auc_score(y_test,y_pred)
# Out:
# 0.8268681144293748

# %%
y_p=model.predict(x_test)
count=[0,0]
for value in y_p:
    if value>0.5:
        count[1]+=1
    else:
        count[0]+=1
print((count[0]/len(y_p))*100,end='')
print('% of predictions belongs to one class')
# Out:
# 85.416% of predictions belongs to one class

# %% [markdown]
# # Trying other models

# %%
rfr=RandomForestClassifier(random_state=1)
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
# Out:
# 0.9832191780821918

# %%
from sklearn.metrics import roc_auc_score

y_pred=rfr.predict_proba(x_test)
temp=[]
for value in y_pred:
    temp.append(value[1])
y_pred=temp
roc_auc_score(y_test,y_pred)
# Out:
# 0.8036954651474624

# %%
y_p=rfr.predict(x_test)
count=[0,0]
for value in y_p:
    if value>0.5:
        count[1]+=1
    else:
        count[0]+=1
print((count[0]/len(y_p))*100,end='')
print('% of predictions belongs to one class')
# Out:
# 79.07733333333333% of predictions belongs to one class

# %% [markdown]
# # Preparing data for submission

# %%
x_train=combine[0].drop(['SeriousDlqin2yrs'],axis=1)

# %%
submission_data=test[x_train.columns]
submission_data=ss.transform(submission_data)
submission_data=np.expand_dims(submission_data,axis=1)

# %%
y_predicted=model.predict(submission_data)
y_predicted=np.squeeze(y_predicted)

# %%
test.index
# Out:
# RangeIndex(start=0, stop=101503, step=1)

# %%
submission=pd.DataFrame()
submission['Id']=np.arange(1,101504)
submission['Probability']=y_predicted

# %%
submission.to_csv('NNMODEL.csv',index=False)

# %% [markdown]
# # Saving the model

# %%
model.save('nn.h5')

# %%
model=keras.models.load_model('nn.h5')
